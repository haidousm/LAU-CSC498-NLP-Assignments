# %%
import nltk
from nltk.book import *
from nltk.stem.porter import *
from nltk.stem import * 

from nltk import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import Counter


from nltk.tokenize import RegexpTokenizer #regular expression tokenizer
import re  # regular expression module

from nltk import FreqDist

from nltk.corpus import gutenberg as g
from nltk.corpus import brown
from nltk.corpus import nps_chat
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
nltk.help.upenn_tagset('VBZ')
# Out:
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...

# %%
nltk.help.upenn_tagset('NN.*') # regular expression
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...

# %%
nltk.help.brown_tagset('TO')
# Out:
# TO: infinitival to
#     to t'

# %%
nltk.corpus.brown.readme()
# Out:
# 'BROWN CORPUS\n\nA Standard Corpus of Present-Day Edited American\nEnglish, for use with Digital Computers.\n\nby W. N. Francis and H. Kucera (1964)\nDepartment of Linguistics, Brown University\nProvidence, Rhode Island, USA\n\nRevised 1971, Revised and Amplified 1979\n\nhttp://www.hit.uib.no/icame/brown/bcm.html\n\nDistributed with the permission of the copyright holder,\nredistribution permitted.\n'

# %% [markdown]
# ### Tagging with pos_tag

# %%
text = "Hello welcome to the world of learning the categorization and POS Tagging with NLTK and Python"
tok_text = word_tokenize(text)
nltk.pos_tag(tok_text)
# Out:
# [('Hello', 'NNP'),
#  ('welcome', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('learning', 'VBG'),
#  ('the', 'DT'),
#  ('categorization', 'NN'),
#  ('and', 'CC'),
#  ('POS', 'NNP'),
#  ('Tagging', 'NNP'),
#  ('with', 'IN'),
#  ('NLTK', 'NNP'),
#  ('and', 'CC'),
#  ('Python', 'NNP')]

# %%
# access individual (token,tag)
tg_text = nltk.pos_tag(tok_text)
tg_text
# Out:
# [('Hello', 'NNP'),
#  ('welcome', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('of', 'IN'),
#  ('learning', 'VBG'),
#  ('the', 'DT'),
#  ('categorization', 'NN'),
#  ('and', 'CC'),
#  ('POS', 'NNP'),
#  ('Tagging', 'NNP'),
#  ('with', 'IN'),
#  ('NLTK', 'NNP'),
#  ('and', 'CC'),
#  ('Python', 'NNP')]

# %%
# Tagged Corpora

tagged_token = nltk.tag.str2tuple('Learn/VB')

print(tagged_token[0])
print(tagged_token[1])

print(tagged_token)
# Out:
# Learn
# VB
# ('Learn', 'VB')

# %% [markdown]
# ### Corpus reader functions are named based on the type of information they return.

# %% [markdown]
# #### Tagged words method

# %%
# Reading a tagged corpora

nltk.corpus.brown.tagged_words(categories='romance')[1:50]
# Out:
# [('neither', 'CC'),
#  ('liked', 'VBD'),
#  ('nor', 'CC'),
#  ('disliked', 'VBD'),
#  ('the', 'AT'),
#  ('Old', 'JJ-TL'),
#  ('Man', 'NN-TL'),
#  ('.', '.'),
#  ('To', 'IN'),
#  ('them', 'PPO'),
#  ('he', 'PPS'),
#  ('could', 'MD'),
#  ('have', 'HV'),
#  ('been', 'BEN'),
#  ('the', 'AT'),
#  ('broken', 'VBN'),
#  ('bell', 'NN'),
#  ('in', 'IN'),
#  ('the', 'AT'),
#  ('church', 'NN'),
#  ('tower', 'NN'),
#  ('which', 'WDT'),
#  ('rang', 'VBD'),
#  ('before', 'IN'),
#  ('and', 'CC'),
#  ('after', 'IN'),
#  ('Mass', 'NN-TL'),
#  (',', ','),
#  ('and', 'CC'),
#  ('at', 'IN'),
#  ('noon', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('at', 'IN'),
#  ('six', 'CD'),
#  ('each', 'DT'),
#  ('evening', 'NN'),
#  ('--', '--'),
#  ('its', 'PP$'),
#  ('tone', 'NN'),
#  (',', ','),
#  ('repetitive', 'JJ'),
#  (',', ','),
#  ('monotonous', 'JJ'),
#  (',', ','),
#  ('never', 'RB'),
#  ('breaking', 'VBG'),
#  ('the', 'AT'),
#  ('boredom', 'NN')]

# %%
# Reading a tagged corpora

nltk.corpus.brown.tagged_words(categories='romance',tagset='universal')[1:50]
# Out:
# [('neither', 'CONJ'),
#  ('liked', 'VERB'),
#  ('nor', 'CONJ'),
#  ('disliked', 'VERB'),
#  ('the', 'DET'),
#  ('Old', 'ADJ'),
#  ('Man', 'NOUN'),
#  ('.', '.'),
#  ('To', 'ADP'),
#  ('them', 'PRON'),
#  ('he', 'PRON'),
#  ('could', 'VERB'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('broken', 'VERB'),
#  ('bell', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('church', 'NOUN'),
#  ('tower', 'NOUN'),
#  ('which', 'DET'),
#  ('rang', 'VERB'),
#  ('before', 'ADP'),
#  ('and', 'CONJ'),
#  ('after', 'ADP'),
#  ('Mass', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('at', 'ADP'),
#  ('noon', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('at', 'ADP'),
#  ('six', 'NUM'),
#  ('each', 'DET'),
#  ('evening', 'NOUN'),
#  ('--', '.'),
#  ('its', 'DET'),
#  ('tone', 'NOUN'),
#  (',', '.'),
#  ('repetitive', 'ADJ'),
#  (',', '.'),
#  ('monotonous', 'ADJ'),
#  (',', '.'),
#  ('never', 'ADV'),
#  ('breaking', 'VERB'),
#  ('the', 'DET'),
#  ('boredom', 'NOUN')]

# %%
nltk.corpus.brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [('The', 'DET'), ('Fulton', 'NOUN'), ...]

# %%
brown_tagged = brown.tagged_words(categories='adventure')
brown_tagged[1:10]
# Out:
# [('Morgan', 'NP'),
#  ('told', 'VBD'),
#  ('himself', 'PPL'),
#  ('he', 'PPS'),
#  ('would', 'MD'),
#  ('forget', 'VB'),
#  ('Ann', 'NP'),
#  ('Turner', 'NP'),
#  ('.', '.')]

# %%
brown_tagged = brown.tagged_words(tagset='universal')
brown_tagged[0:10]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP')]

# %%
brown.fileids()
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44',
#  'cb01',
#  'cb02',
#  'cb03',
#  'cb04',
#  'cb05',
#  'cb06',
#  'cb07',
#  'cb08',
#  'cb09',
#  'cb10',
#  'cb11',
#  'cb12',
#  'cb13',
#  'cb14',
#  'cb15',
#  'cb16',
#  'cb17',
#  'cb18',
#  'cb19',
#  'cb20',
#  'cb21',
#  'cb22',
#  'cb23',
#  'cb24',
#  'cb25',
#  'cb26',
#  'cb27',
#  'cc01',
#  'cc02',
#  'cc03',
#  'cc04',
#  'cc05',
#  'cc06',
#  'cc07',
#  'cc08',
#  'cc09',
#  'cc10',
#  'cc11',
#  'cc12',
#  'cc13',
#  'cc14',
#  'cc15',
#  'cc16',
#  'cc17',
#  'cd01',
#  'cd02',
#  'cd03',
#  'cd04',
#  'cd05',
#  'cd06',
#  'cd07',
#  'cd08',
#  'cd09',
#  'cd10',
#  'cd11',
#  'cd12',
#  'cd13',
#  'cd14',
#  'cd15',
#  'cd16',
#  'cd17',
#  'ce01',
#  'ce02',
#  'ce03',
#  'ce04',
#  'ce05',
#  'ce06',
#  'ce07',
#  'ce08',
#  'ce09',
#  'ce10',
#  'ce11',
#  'ce12',
#  'ce13',
#  'ce14',
#  'ce15',
#  'ce16',
#  'ce17',
#  'ce18',
#  'ce19',
#  'ce20',
#  'ce21',
#  'ce22',
#  'ce23',
#  'ce24',
#  'ce25',
#  'ce26',
#  'ce27',
#  'ce28',
#  'ce29',
#  'ce30',
#  'ce31',
#  'ce32',
#  'ce33',
#  'ce34',
#  'ce35',
#  'ce36',
#  'cf01',
#  'cf02',
#  'cf03',
#  'cf04',
#  'cf05',
#  'cf06',
#  'cf07',
#  'cf08',
#  'cf09',
#  'cf10',
#  'cf11',
#  'cf12',
#  'cf13',
#  'cf14',
#  'cf15',
#  'cf16',
#  'cf17',
#  'cf18',
#  'cf19',
#  'cf20',
#  'cf21',
#  'cf22',
#  'cf23',
#  'cf24',
#  'cf25',
#  'cf26',
#  'cf27',
#  'cf28',
#  'cf29',
#  'cf30',
#  'cf31',
#  'cf32',
#  'cf33',
#  'cf34',
#  'cf35',
#  'cf36',
#  'cf37',
#  'cf38',
#  'cf39',
#  'cf40',
#  'cf41',
#  'cf42',
#  'cf43',
#  'cf44',
#  'cf45',
#  'cf46',
#  'cf47',
#  'cf48',
#  'cg01',
#  'cg02',
#  'cg03',
#  'cg04',
#  'cg05',
#  'cg06',
#  'cg07',
#  'cg08',
#  'cg09',
#  'cg10',
#  'cg11',
#  'cg12',
#  'cg13',
#  'cg14',
#  'cg15',
#  'cg16',
#  'cg17',
#  'cg18',
#  'cg19',
#  'cg20',
#  'cg21',
#  'cg22',
#  'cg23',
#  'cg24',
#  'cg25',
#  'cg26',
#  'cg27',
#  'cg28',
#  'cg29',
#  'cg30',
#  'cg31',
#  'cg32',
#  'cg33',
#  'cg34',
#  'cg35',
#  'cg36',
#  'cg37',
#  'cg38',
#  'cg39',
#  'cg40',
#  'cg41',
#  'cg42',
#  'cg43',
#  'cg44',
#  'cg45',
#  'cg46',
#  'cg47',
#  'cg48',
#  'cg49',
#  'cg50',
#  'cg51',
#  'cg52',
#  'cg53',
#  'cg54',
#  'cg55',
#  'cg56',
#  'cg57',
#  'cg58',
#  'cg59',
#  'cg60',
#  'cg61',
#  'cg62',
#  'cg63',
#  'cg64',
#  'cg65',
#  'cg66',
#  'cg67',
#  'cg68',
#  'cg69',
#  'cg70',
#  'cg71',
#  'cg72',
#  'cg73',
#  'cg74',
#  'cg75',
#  'ch01',
#  'ch02',
#  'ch03',
#  'ch04',
#  'ch05',
#  'ch06',
#  'ch07',
#  'ch08',
#  'ch09',
#  'ch10',
#  'ch11',
#  'ch12',
#  'ch13',
#  'ch14',
#  'ch15',
#  'ch16',
#  'ch17',
#  'ch18',
#  'ch19',
#  'ch20',
#  'ch21',
#  'ch22',
#  'ch23',
#  'ch24',
#  'ch25',
#  'ch26',
#  'ch27',
#  'ch28',
#  'ch29',
#  'ch30',
#  'cj01',
#  'cj02',
#  'cj03',
#  'cj04',
#  'cj05',
#  'cj06',
#  'cj07',
#  'cj08',
#  'cj09',
#  'cj10',
#  'cj11',
#  'cj12',
#  'cj13',
#  'cj14',
#  'cj15',
#  'cj16',
#  'cj17',
#  'cj18',
#  'cj19',
#  'cj20',
#  'cj21',
#  'cj22',
#  'cj23',
#  'cj24',
#  'cj25',
#  'cj26',
#  'cj27',
#  'cj28',
#  'cj29',
#  'cj30',
#  'cj31',
#  'cj32',
#  'cj33',
#  'cj34',
#  'cj35',
#  'cj36',
#  'cj37',
#  'cj38',
#  'cj39',
#  'cj40',
#  'cj41',
#  'cj42',
#  'cj43',
#  'cj44',
#  'cj45',
#  'cj46',
#  'cj47',
#  'cj48',
#  'cj49',
#  'cj50',
#  'cj51',
#  'cj52',
#  'cj53',
#  'cj54',
#  'cj55',
#  'cj56',
#  'cj57',
#  'cj58',
#  'cj59',
#  'cj60',
#  'cj61',
#  'cj62',
#  'cj63',
#  'cj64',
#  'cj65',
#  'cj66',
#  'cj67',
#  'cj68',
#  'cj69',
#  'cj70',
#  'cj71',
#  'cj72',
#  'cj73',
#  'cj74',
#  'cj75',
#  'cj76',
#  'cj77',
#  'cj78',
#  'cj79',
#  'cj80',
#  'ck01',
#  'ck02',
#  'ck03',
#  'ck04',
#  'ck05',
#  'ck06',
#  'ck07',
#  'ck08',
#  'ck09',
#  'ck10',
#  'ck11',
#  'ck12',
#  'ck13',
#  'ck14',
#  'ck15',
#  'ck16',
#  'ck17',
#  'ck18',
#  'ck19',
#  'ck20',
#  'ck21',
#  'ck22',
#  'ck23',
#  'ck24',
#  'ck25',
#  'ck26',
#  'ck27',
#  'ck28',
#  'ck29',
#  'cl01',
#  'cl02',
#  'cl03',
#  'cl04',
#  'cl05',
#  'cl06',
#  'cl07',
#  'cl08',
#  'cl09',
#  'cl10',
#  'cl11',
#  'cl12',
#  'cl13',
#  'cl14',
#  'cl15',
#  'cl16',
#  'cl17',
#  'cl18',
#  'cl19',
#  'cl20',
#  'cl21',
#  'cl22',
#  'cl23',
#  'cl24',
#  'cm01',
#  'cm02',
#  'cm03',
#  'cm04',
#  'cm05',
#  'cm06',
#  'cn01',
#  'cn02',
#  'cn03',
#  'cn04',
#  'cn05',
#  'cn06',
#  'cn07',
#  'cn08',
#  'cn09',
#  'cn10',
#  'cn11',
#  'cn12',
#  'cn13',
#  'cn14',
#  'cn15',
#  'cn16',
#  'cn17',
#  'cn18',
#  'cn19',
#  'cn20',
#  'cn21',
#  'cn22',
#  'cn23',
#  'cn24',
#  'cn25',
#  'cn26',
#  'cn27',
#  'cn28',
#  'cn29',
#  'cp01',
#  'cp02',
#  'cp03',
#  'cp04',
#  'cp05',
#  'cp06',
#  'cp07',
#  'cp08',
#  'cp09',
#  'cp10',
#  'cp11',
#  'cp12',
#  'cp13',
#  'cp14',
#  'cp15',
#  'cp16',
#  'cp17',
#  'cp18',
#  'cp19',
#  'cp20',
#  'cp21',
#  'cp22',
#  'cp23',
#  'cp24',
#  'cp25',
#  'cp26',
#  'cp27',
#  'cp28',
#  'cp29',
#  'cr01',
#  'cr02',
#  'cr03',
#  'cr04',
#  'cr05',
#  'cr06',
#  'cr07',
#  'cr08',
#  'cr09']

# %%
brown.sents()
# Out:
# [['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.'], ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.'], ...]

# %%
brown_tagged = brown.tagged_words(categories='science_fiction', tagset='universal')
print("First 10 word-tag pairs: ", brown_tagged[1:10])

tag_fd = nltk.FreqDist(tag for (word, tag) in brown_tagged)

print("\n Most common tags: ", tag_fd.most_common())
print("  \n Keys: ", tag_fd.keys())
# Out:
# First 10 word-tag pairs:  [('that', 'ADP'), ('he', 'PRON'), ('knew', 'VERB'), ('himself', 'PRON'), ('to', 'PRT'), ('be', 'VERB'), ('self', 'NOUN'), ('he', 'PRON'), ('was', 'VERB')]
#
#  Most common tags:  [('NOUN', 2747), ('VERB', 2579), ('.', 2428), ('DET', 1582), ('ADP', 1451), ('PRON', 934), ('ADJ', 929), ('ADV', 828), ('PRT', 483), ('CONJ', 416), ('NUM', 79), ('X', 14)]
#
#  Keys:  dict_keys(['ADV', 'ADP', 'PRON', 'VERB', 'PRT', 'NOUN', 'ADJ', 'DET', '.', 'CONJ', 'NUM', 'X'])

# %% [markdown]
# #### Tagged sentences method

# %%
brown_sents_tag = brown.tagged_sents('ca05')
brown_sents_tag[0:2]
# Out:
# [[('East', 'JJ-TL'),
#   ('Providence', 'NP-TL'),
#   ('should', 'MD'),
#   ('organize', 'VB'),
#   ('its', 'PP$'),
#   ('civil', 'JJ'),
#   ('defense', 'NN'),
#   ('setup', 'NN'),
#   ('and', 'CC'),
#   ('begin', 'VB'),
#   ('by', 'IN'),
#   ('appointing', 'VBG'),
#   ('a', 'AT'),
#   ('full-time', 'JJ'),
#   ('director', 'NN'),
#   (',', ','),
#   ('Raymond', 'NP'),
#   ('H.', 'NP'),
#   ('Hawksley', 'NP'),
#   (',', ','),
#   ('the', 'AT'),
#   ('present', 'JJ'),
#   ('city', 'NN'),
#   ('CD', 'NN'),
#   ('head', 'NN'),
#   (',', ','),
#   ('believes', 'VBZ'),
#   ('.', '.')],
#  [('Mr.', 'NP'),
#   ('Hawksley', 'NP'),
#   ('said', 'VBD'),
#   ('yesterday', 'NR'),
#   ('he', 'PPS'),
#   ('would', 'MD'),
#   ('be', 'BE'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('before', 'IN'),
#   ('the', 'AT'),
#   ('city', 'NN'),
#   ('council', 'NN'),
#   ('``', '``'),
#   ('or', 'CC'),
#   ('anyone', 'PN'),
#   ('else', 'RB'),
#   ('locally', 'RB'),
#   ("''", "''"),
#   ('to', 'TO'),
#   ('outline', 'VB'),
#   ('his', 'PP$'),
#   ('proposal', 'NN'),
#   ('at', 'IN'),
#   ('the', 'AT'),
#   ('earliest', 'JJT'),
#   ('possible', 'JJ'),
#   ('time', 'NN'),
#   ('.', '.')]]

# %%
chat_tags = nltk.corpus.nps_chat.tagged_words()

chat_tags[100:120]
# Out:
# [('my', 'PRP$'),
#  ('cousin', 'NN'),
#  ('drew', 'VBD'),
#  ('a', 'DT'),
#  ('messed', 'VBD'),
#  ('up', 'RP'),
#  ('pic', 'NN'),
#  ('on', 'IN'),
#  ('my', 'PRP$'),
#  ('cast', 'NN'),
#  ('PART', 'VB'),
#  ('24', 'CD'),
#  ('/', 'CC'),
#  ('m', 'NN'),
#  ('boo', 'UH'),
#  ('.', '.'),
#  ('26', 'CD'),
#  ('/', 'CC'),
#  ('m', 'NN'),
#  ('and', 'CC')]

# %%
text = nltk.Text(word.lower() for word in brown.words())
type(text)
# Out:
# nltk.text.Text

# %% [markdown]
# # Unigrams - Bigrams - Trigrams - Ngrams

# %%
text = "Toto, I've a feeling we're not in Kansas anymore." # The Wizard of Oz (1939)

#tokenize first
text_toks = word_tokenize(text)
print(text_toks)

list(nltk.bigrams(text_toks))
# Out:
# ['Toto', ',', 'I', "'ve", 'a', 'feeling', 'we', "'re", 'not', 'in', 'Kansas', 'anymore', '.']
# [('Toto', ','),
#  (',', 'I'),
#  ('I', "'ve"),
#  ("'ve", 'a'),
#  ('a', 'feeling'),
#  ('feeling', 'we'),
#  ('we', "'re"),
#  ("'re", 'not'),
#  ('not', 'in'),
#  ('in', 'Kansas'),
#  ('Kansas', 'anymore'),
#  ('anymore', '.')]

# %%
list(nltk.trigrams(text_toks))
# Out:
# [('Toto', ',', 'I'),
#  (',', 'I', "'ve"),
#  ('I', "'ve", 'a'),
#  ("'ve", 'a', 'feeling'),
#  ('a', 'feeling', 'we'),
#  ('feeling', 'we', "'re"),
#  ('we', "'re", 'not'),
#  ("'re", 'not', 'in'),
#  ('not', 'in', 'Kansas'),
#  ('in', 'Kansas', 'anymore'),
#  ('Kansas', 'anymore', '.')]

# %%
list(nltk.ngrams(text_toks, 3))
# Out:
# [('Toto', ',', 'I'),
#  (',', 'I', "'ve"),
#  ('I', "'ve", 'a'),
#  ("'ve", 'a', 'feeling'),
#  ('a', 'feeling', 'we'),
#  ('feeling', 'we', "'re"),
#  ('we', "'re", 'not'),
#  ("'re", 'not', 'in'),
#  ('not', 'in', 'Kansas'),
#  ('in', 'Kansas', 'anymore'),
#  ('Kansas', 'anymore', '.')]

# %% [markdown]
# ## Let’s inspect some tagged text to see what parts-of-speech occur before a noun, with the most frequent ones first. To begin with, we construct a list of bigrams whose members are themselves word-tag pairs, such as (('The', 'DET'), ('Fulton', 'NP')) and (('Fulton', 'NP'), ('County', 'N')).

# %%
# Repeat previous example

brown_tagged = brown.tagged_words(categories='news', tagset='universal')
print("First 10 word-tag pairs: ", brown_tagged[0:10])

tag_fd = nltk.FreqDist(tag for (word, tag) in brown_tagged)

print("\n Most common tags: ", tag_fd.most_common(10))
# print("  \n Keys: ", tag_fd.keys())
# Out:
# First 10 word-tag pairs:  [('The', 'DET'), ('Fulton', 'NOUN'), ('County', 'NOUN'), ('Grand', 'ADJ'), ('Jury', 'NOUN'), ('said', 'VERB'), ('Friday', 'NOUN'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP')]
#
#  Most common tags:  [('NOUN', 30654), ('VERB', 14399), ('ADP', 12355), ('.', 11928), ('DET', 11389), ('ADJ', 6706), ('ADV', 3349), ('CONJ', 2717), ('PRON', 2535), ('PRT', 2264)]

# %%
word_tag_pairs = nltk.bigrams(brown_tagged)
# print(list(word_tag_pairs)[0:10])
freq = nltk.FreqDist(a[1] for (a, b) in word_tag_pairs if b[1] =='NOUN')

list(freq.most_common(10))
# Out:
# [('NOUN', 7959),
#  ('DET', 7373),
#  ('ADJ', 4761),
#  ('ADP', 3781),
#  ('.', 2796),
#  ('VERB', 1842),
#  ('CONJ', 938),
#  ('NUM', 894),
#  ('ADV', 186),
#  ('PRT', 94)]

# %%
# getting bigrams out of a gutenberg text

sample = g.fileids()[0]

emma_text = g.raw(sample)
print(type(text))

emma_tokens = word_tokenize(text)

emma_pairs = nltk.trigrams(emma_tokens)
list(emma_pairs)[1:10]
# Out:
# <class 'str'>
# [(',', 'I', "'ve"),
#  ('I', "'ve", 'a'),
#  ("'ve", 'a', 'feeling'),
#  ('a', 'feeling', 'we'),
#  ('feeling', 'we', "'re"),
#  ('we', "'re", 'not'),
#  ("'re", 'not', 'in'),
#  ('not', 'in', 'Kansas'),
#  ('in', 'Kansas', 'anymore')]

# %%
# getting bigrams out of a brown text

sample_brown = brown.fileids()[2]

brown_text = brown.raw(sample_brown)

brown_tokens = word_tokenize(brown_text) # you can use split() here too

brown_pairs  = nltk.bigrams(brown_tokens)

list(brown_pairs)[0:10]
# Out:
# [('Several/ap', 'defendants/nns'),
#  ('defendants/nns', 'in/in'),
#  ('in/in', 'the/at'),
#  ('the/at', 'Summerdale/np'),
#  ('Summerdale/np', 'police/nn'),
#  ('police/nn', 'burglary/nn'),
#  ('burglary/nn', 'trial/nn'),
#  ('trial/nn', 'made/vbd'),
#  ('made/vbd', 'statements/nns'),
#  ('statements/nns', 'indicating/vbg')]

# %%
brown_text.split()
# Out:
# ['Several/ap',
#  'defendants/nns',
#  'in/in',
#  'the/at',
#  'Summerdale/np',
#  'police/nn',
#  'burglary/nn',
#  'trial/nn',
#  'made/vbd',
#  'statements/nns',
#  'indicating/vbg',
#  'their/pp$',
#  'guilt/nn',
#  'at/in',
#  'the/at',
#  'time/nn',
#  'of/in',
#  'their/pp$',
#  'arrest/nn',
#  ',/,',
#  'Judge/nn-tl',
#  'James/np',
#  'B./np',
#  'Parsons/np',
#  'was/bedz',
#  'told/vbn',
#  'in/in',
#  'Criminal/jj-tl',
#  'court/nn',
#  'yesterday/nr',
#  './.',
#  'The/at',
#  'disclosure/nn',
#  'by/in',
#  'Charles/np',
#  'Bellows/np',
#  ',/,',
#  'chief/jjs',
#  'defense/nn',
#  'counsel/nn',
#  ',/,',
#  'startled/vbd',
#  'observers/nns',
#  'and/cc',
#  'was/bedz',
#  'viewed/vbn',
#  'as/cs',
#  'the/at',
#  'prelude/nn',
#  'to/in',
#  'a/at',
#  'quarrel/nn',
#  'between/in',
#  'the/at',
#  'six/cd',
#  'attorneys/nns',
#  'representing/vbg',
#  'the/at',
#  'eight/cd',
#  'former/ap',
#  'policemen/nns',
#  'now/rb',
#  'on/in',
#  'trial/nn',
#  './.',
#  'Bellows/np',
#  'made/vbd',
#  'the/at',
#  'disclosure/nn',
#  'when/wrb',
#  'he/pps',
#  'asked/vbd',
#  'Judge/nn-tl',
#  'Parsons/np',
#  'to/to',
#  'grant/vb',
#  'his/pp$',
#  'client/nn',
#  ',/,',
#  'Alan/np',
#  'Clements/np',
#  ',/,',
#  '30/cd',
#  ',/,',
#  'a/at',
#  'separate/jj',
#  'trial/nn',
#  './.',
#  'Bellows/np',
#  'made/vbd',
#  'the/at',
#  'request/nn',
#  'while/cs',
#  'the/at',
#  'all-woman/jj',
#  'jury/nn',
#  'was/bedz',
#  'out/in',
#  'of/in',
#  'the/at',
#  'courtroom/nn',
#  './.',
#  'Fears/vbz-hl',
#  'prejudicial/jj-hl',
#  'aspects/nns-hl',
#  '``/``',
#  'The/at',
#  'statements/nns',
#  'may/md',
#  'be/be',
#  'highly/ql',
#  'prejudicial/jj',
#  'to/in',
#  'my/pp$',
#  'client/nn',
#  "''/''",
#  ',/,',
#  'Bellows/np',
#  'told/vbd',
#  'the/at',
#  'court/nn',
#  './.',
#  '``/``',
#  'Some/dti',
#  'of/in',
#  'the/at',
#  'defendants/nns',
#  'strongly/rb',
#  'indicated/vbd',
#  'they/ppss',
#  'knew/vbd',
#  'they/ppss',
#  'were/bed',
#  'receiving/vbg',
#  'stolen/vbn',
#  'property/nn',
#  './.',
#  'It/pps',
#  'is/bez',
#  'impossible/jj',
#  'to/to',
#  'get/vb',
#  'a/at',
#  'fair/jj',
#  'trial/nn',
#  'when/wrb',
#  'some/dti',
#  'of/in',
#  'the/at',
#  'defendants/nns',
#  'made/vbd',
#  'statements/nns',
#  'involving/vbg',
#  'themselves/ppls',
#  'and/cc',
#  'others/nns',
#  "''/''",
#  './.',
#  'Judge/nn-tl',
#  'Parsons/np',
#  'leaned/vbd',
#  'over/in',
#  'the/at',
#  'bench/nn',
#  'and/cc',
#  'inquired/vbd',
#  ',/,',
#  '``/``',
#  'You/ppss',
#  'mean/vb',
#  'some/dti',
#  'of/in',
#  'the/at',
#  'defendants/nns',
#  'made/vbd',
#  'statements/nns',
#  'admitting/vbg',
#  'this/dt',
#  "''/''",
#  '?/.',
#  '?/.',
#  '``/``',
#  'Yes/rb',
#  ',/,',
#  'your/pp$',
#  'honor/nn',
#  "''/''",
#  ',/,',
#  'replied/vbd',
#  'Bellows/np',
#  './.',
#  '``/``',
#  'What/wdt',
#  'this/dt',
#  'amounts/vbz',
#  'to/in',
#  ',/,',
#  'if/cs',
#  'true/jj',
#  ',/,',
#  'is/bez',
#  'that/cs',
#  'there/ex',
#  'will/md',
#  'be/be',
#  'a/at',
#  'free-for-all/jj',
#  'fight/nn',
#  'in/in',
#  'this/dt',
#  'case/nn',
#  './.',
#  'There/ex',
#  'is/bez',
#  'a/at',
#  'conflict/nn',
#  'among/in',
#  'the/at',
#  'defendants/nns',
#  "''/''",
#  './.',
#  'Washington/np-hl',
#  ',/,-hl',
#  'July/np-hl',
#  '24/cd-hl',
#  '--/--',
#  'President/nn-tl',
#  'Kennedy/np',
#  'today/nr',
#  'pushed/vbd',
#  'aside/rb',
#  'other/ap',
#  'White/jj-tl',
#  'House/nn-tl',
#  'business/nn',
#  'to/to',
#  'devote/vb',
#  'all/abn',
#  'his/pp$',
#  'time/nn',
#  'and/cc',
#  'attention/nn',
#  'to/in',
#  'working/vbg',
#  'on/in',
#  'the/at',
#  'Berlin/np',
#  'crisis/nn',
#  'address/nn',
#  'he/pps',
#  'will/md',
#  'deliver/vb',
#  'tomorrow/nr',
#  'night/nn',
#  'to/in',
#  'the/at',
#  'American/jj',
#  'people/nns',
#  'over/in',
#  'nationwide/jj',
#  'television/nn',
#  'and/cc',
#  'radio/nn',
#  './.',
#  'The/at',
#  'President/nn-tl',
#  'spent/vbd',
#  'much/ap',
#  'of/in',
#  'the/at',
#  'week-end/nn',
#  'at/in',
#  'his/pp$',
#  'summer/nn',
#  'home/nn',
#  'on/in',
#  'Cape/nn-tl',
#  'Cod/nn-tl',
#  'writing/vbg',
#  'the/at',
#  'first/od',
#  'drafts/nns',
#  'of/in',
#  'portions/nns',
#  'of/in',
#  'the/at',
#  'address/nn',
#  'with/in',
#  'the/at',
#  'help/nn',
#  'of/in',
#  'White/jj-tl',
#  'House/nn-tl',
#  'aids/nns',
#  'in/in',
#  'Washington/np',
#  'with/in',
#  'whom/wpo',
#  'he/pps',
#  'talked/vbd',
#  'by/in',
#  'telephone/nn',
#  './.',
#  'Shortly/rb',
#  'after/cs',
#  'the/at',
#  'Chief/jjs-tl',
#  'Executive/nn-tl',
#  'returned/vbd',
#  'to/in',
#  'Washington/np',
#  'in/in',
#  'midmorning/nn',
#  'from/in',
#  'Hyannis/np',
#  'Port/nn-tl',
#  ',/,',
#  'Mass./np',
#  ',/,',
#  'a/at',
#  'White/jj-tl',
#  'House/nn-tl',
#  'spokesman/nn',
#  'said/vbd',
#  'the/at',
#  'address/nn',
#  'text/nn',
#  'still/rb',
#  'had/hvd',
#  '``/``',
#  'quite/abl',
#  'a/at',
#  'way/nn',
#  'to/to',
#  'go/vb',
#  "''/''",
#  'toward/in',
#  'completion/nn',
#  './.',
#  'Decisions/nns-hl',
#  'are/ber-hl',
#  'made/vbn-hl',
#  'Asked/vbn',
#  'to/to',
#  'elaborate/vb',
#  ',/,',
#  'Pierre/np',
#  'Salinger/np',
#  ',/,',
#  'White/jj-tl',
#  'House/nn-tl',
#  'press/nn',
#  'secretary/nn',
#  ',/,',
#  'replied/vbd',
#  ',/,',
#  '``/``',
#  'I/ppss',
#  'would/md',
#  'say/vb',
#  "it's/pps+hvz",
#  'got/vbn',
#  'to/to',
#  'go/vb',
#  'thru/in',
#  'several/ap',
#  'more/ap',
#  'drafts/nns',
#  "''/''",
#  './.',
#  'Salinger/np',
#  'said/vbd',
#  'the/at',
#  'work/nn',
#  'President/nn-tl',
#  'Kennedy/np',
#  ',/,',
#  'advisers/nns',
#  ',/,',
#  'and/cc',
#  'members/nns',
#  'of/in',
#  'his/pp$',
#  'staff/nn',
#  'were/bed',
#  'doing/vbg',
#  'on/in',
#  'the/at',
#  'address/nn',
#  'involved/vbd',
#  'composition/nn',
#  'and/cc',
#  'wording/vbg',
#  ',/,',
#  'rather/in',
#  'than/in',
#  'last/ap',
#  'minute/nn',
#  'decisions/nns',
#  'on/in',
#  'administration/nn',
#  'plans/nns',
#  'to/to',
#  'meet/vb',
#  'the/at',
#  'latest/jjt',
#  'Berlin/np',
#  'crisis/nn',
#  'precipitated/vbn',
#  'by/in',
#  "Russia's/np$",
#  'demands/nns',
#  'and/cc',
#  'proposals/nns',
#  'for/in',
#  'the/at',
#  'city/nn',
#  './.',
#  'The/at',
#  'last/ap',
#  '10/cd',
#  'cases/nns',
#  'in/in',
#  'the/at',
#  'investigation/nn',
#  'of/in',
#  'the/at',
#  'Nov./np',
#  '8/cd',
#  'election/nn',
#  'were/bed',
#  'dismissed/vbn',
#  'yesterday/nr',
#  'by/in',
#  'Acting/vbg-tl',
#  'Judge/nn-tl',
#  'John/np',
#  'M./np',
#  'Karns/np',
#  ',/,',
#  'who/wps',
#  'charged/vbd',
#  'that/cs',
#  'the/at',
#  'prosecution/nn',
#  'obtained/vbd',
#  'evidence/nn',
#  '``/``',
#  'by/in',
#  'unfair/jj',
#  'and/cc',
#  'fundamentally/ql',
#  'illegal/jj',
#  'means/nns',
#  "''/''",
#  './.',
#  'Karns/np',
#  'said/vbd',
#  'that/cs',
#  'the/at',
#  'cases/nns',
#  'involved/vbd',
#  'a/at',
#  'matter/nn',
#  '``/``',
#  'of/in',
#  'even/ql',
#  'greater/jjr',
#  'significance/nn',
#  'than/cs',
#  'the/at',
#  'guilt/nn',
#  'or/cc',
#  'innocence/nn',
#  "''/''",
#  'of/in',
#  'the/at',
#  '50/cd',
#  'persons/nns',
#  './.',
#  'He/pps',
#  'said/vbd',
#  'evidence/nn',
#  'was/bedz',
#  'obtained/vbn',
#  '``/``',
#  'in/in',
#  'violation/nn',
#  'of/in',
#  'the/at',
#  'legal/jj',
#  'rights/nns',
#  'of/in',
#  'citizens/nns',
#  "''/''",
#  './.',
#  "Karns'/np$",
#  'ruling/nn',
#  'pertained/vbd',
#  'to/in',
#  'eight/cd',
#  'of/in',
#  'the/at',
#  '10/cd',
#  'cases/nns',
#  './.',
#  'In/in',
#  'the/at',
#  'two/cd',
#  'other/ap',
#  'cases/nns',
#  'he/pps',
#  'ruled/vbd',
#  'that/cs',
#  'the/at',
#  'state/nn',
#  'had/hvd',
#  'been/ben',
#  '``/``',
#  'unable/jj',
#  'to/to',
#  'make/vb',
#  'a/at',
#  'case/nn',
#  "''/''",
#  './.',
#  'Contempt/nn',
#  'proceedings/nns',
#  'originally/rb',
#  'had/hvd',
#  'been/ben',
#  'brought/vbn',
#  'against/in',
#  '677/cd',
#  'persons/nns',
#  'in/in',
#  '133/cd',
#  'precincts/nns',
#  'by/in',
#  'Morris/np',
#  'J./np',
#  'Wexler/np',
#  ',/,',
#  'special/jj',
#  'prosecutor/nn',
#  './.',
#  'Issue/vb-hl',
#  'jury/nn-hl',
#  'subpoenas/nns-hl',
#  'Wexler/np',
#  'admitted/vbd',
#  'in/in',
#  'earlier/jjr',
#  'court/nn',
#  'hearings/nns',
#  'that/cs',
#  'he/pps',
#  'issued/vbd',
#  'grand/jj',
#  'jury/nn',
#  'subpenas/nns',
#  'to/in',
#  'about/rb',
#  '200/cd',
#  'persons/nns',
#  'involved/vbn',
#  'in/in',
#  'the/at',
#  'election/nn',
#  'investigation/nn',
#  ',/,',
#  'questioned/vbd',
#  'the/at',
#  'individuals/nns',
#  'in/in',
#  'the/at',
#  'Criminal/jj-tl',
#  'courts/nns',
#  'building/nn',
#  ',/,',
#  'but/cc',
#  'did/dod',
#  'not/*',
#  'take/vb',
#  'them/ppo',
#  'before/in',
#  'the/at',
#  'grand/jj',
#  'jury/nn',
#  './.',
#  'Mayer/np',
#  'Goldberg/np',
#  ',/,',
#  'attorney/nn',
#  'for/in',
#  'election/nn',
#  'judges/nns',
#  'in/in',
#  'the/at',
#  '58th/od',
#  'precinct/nn',
#  'of/in',
#  'the/at',
#  '23d/od',
#  'ward/nn',
#  ',/,',
#  'argued/vbd',
#  'this/dt',
#  'procedure/nn',
#  'constituted/vbd',
#  'intimidation/nn',
#  './.',
#  'Wexler/np',
#  'has/hvz',
#  'denied/vbn',
#  'repeatedly/rb',
#  'that/cs',
#  'coercion/nn',
#  'was/bedz',
#  'used/vbn',
#  'in/in',
#  'questioning/vbg',
#  './.',
#  'Karns/np',
#  'said/vbd',
#  'it/pps',
#  'was/bedz',
#  'a/at',
#  '``/``',
#  'wrongful/jj',
#  'act/nn',
#  "''/''",
#  'for/in',
#  'Wexler/np',
#  'to/to',
#  'take/vb',
#  'statements/nns',
#  '``/``',
#  'privately/rb',
#  'and/cc',
#  'outside/in',
#  'of/in',
#  'the/at',
#  'grand/jj',
#  'jury/nn',
#  'room/nn',
#  "''/''",
#  './.',
#  'He/pps',
#  'said/vbd',
#  'this/dt',
#  'constituted/vbd',
#  'a/at',
#  '``/``',
#  'very/ql',
#  'serious/jj',
#  'misuse/nn',
#  "''/''",
#  'of/in',
#  'the/at',
#  'Criminal/jj-tl',
#  'court/nn-tl',
#  'processes/nns',
#  './.',
#  '``/``',
#  'Actually/rb',
#  ',/,',
#  'the/at',
#  'abuse/nn',
#  'of/in',
#  'the/at',
#  'process/nn',
#  'may/md',
#  'have/hv',
#  'constituted/vbn',
#  'a/at',
#  'contempt/nn',
#  'of/in',
#  'the/at',
#  'Criminal/jj-tl',
#  'court/nn-tl',
#  'of/in-tl',
#  'Cook/np',
#  'county/nn',
#  ',/,',
#  'altho/cs',
#  'vindication/nn',
#  'of/in',
#  'the/at',
#  'authority/nn',
#  'of/in',
#  'that/dt',
#  'court/nn',
#  'is/bez',
#  'not/*',
#  'the/at',
#  'function/nn',
#  'of/in',
#  'this/dt',
#  'court/nn',
#  "''/''",
#  ',/,',
#  'said/vbd',
#  'Karns/np',
#  ',/,',
#  'who/wps',
#  'is/bez',
#  'a/at',
#  'City/nn-tl',
#  'judge/nn',
#  'in/in',
#  'East/jj-tl',
#  'St./np-tl',
#  'Louis/np-tl',
#  'sitting/vbg',
#  'in/in',
#  'Cook/np-tl',
#  'County/nn-tl',
#  'court/nn-tl',
#  './.',
#  'Faced/vbd-hl',
#  'seven/cd-hl',
#  'cases/nns-hl',
#  'Karns/np',
#  'had/hvd',
#  'been/ben',
#  'scheduled/vbn',
#  'this/dt',
#  'week/nn',
#  'to/to',
#  'hear/vb',
#  'seven/cd',
#  'cases/nns',
#  'involving/vbg',
#  '35/cd',
#  'persons/nns',
#  './.',
#  'Wexler/np',
#  'had/hvd',
#  'charged/vbn',
#  'the/at',
#  'precinct/nn',
#  'judges/nns',
#  'in/in',
#  'these/dts',
#  'cases/nns',
#  'with/in',
#  '``/``',
#  'complementary/jj',
#  "''/''",
#  'miscount/nn',
#  'of/in',
#  'the/at',
#  'vote/nn',
#  ',/,',
#  'in/in',
#  'which/wdt',
#  'votes/nns',
#  'would/md',
#  'be/be',
#  'taken/vbn',
#  'from/in',
#  'one/cd',
#  'candidate/nn',
#  'and/cc',
#  'given/vbn',
#  'to/in',
#  'another/dt',
#  './.',
#  'The/at',
#  'cases/nns',
#  'involved/vbd',
#  'judges/nns',
#  'in/in',
#  'the/at',
#  '33d/od',
#  ',/,',
#  '24th/od',
#  ',/,',
#  'and/cc',
#  '42d/od',
#  'precincts/nns',
#  'of/in',
#  'the/at',
#  '31st/od',
#  'ward/nn',
#  ',/,',
#  'the/at',
#  '21st/od',
#  'and/cc',
#  '28th/od',
#  'precincts/nns',
#  'of/in',
#  'the/at',
#  '29th/od',
#  'ward/nn',
#  ',/,',
#  'the/at',
#  '18th/od',
#  'precinct/nn',
#  'of/in',
#  'the/at',
#  '4th/od',
#  'ward/nn',
#  ',/,',
#  'and/cc',
#  'the/at',
#  '9th/od',
#  'precinct/nn',
#  'of/in',
#  'the/at',
#  '23d/od',
#  'ward/nn',
#  './.',
#  'The/at',
#  'case/nn',
#  'of/in',
#  'the/at',
#  'judges/nns',
#  'in/in',
#  'the/at',
#  '58th/od',
#  'precinct/nn',
#  'of/in',
#  'the/at',
#  '23d/od',
#  'ward/nn',
#  'had/hvd',
#  'been/ben',
#  'heard/vbn',
#  'previously/rb',
#  'and/cc',
#  'taken/vbn',
#  'under/in',
#  'advisement/nn',
#  'by/in',
#  'Karns/np',
#  './.',
#  'Two/cd',
#  'other/ap',
#  'cases/nns',
#  'also/rb',
#  'were/bed',
#  'under/in',
#  'advisement/nn',
#  './.',
#  'Claims/vbz-hl',
#  'precedent/nn-hl',
#  'lacking/vbg-hl',
#  'After/in',
#  'reading/vbg',
#  'his/pp$',
#  'statement/nn',
#  'discharging/vbg',
#  'the/at',
#  '23d/od',
#  'ward/nn',
#  'case/nn',
#  ',/,',
#  'Karns/np',
#  'told/vbd',
#  'Wexler/np',
#  'that/cs',
#  'if/cs',
#  'the/at',
#  'seven/cd',
#  'cases/nns',
#  'scheduled/vbn',
#  'for/in',
#  'trial/nn',
#  'also/rb',
#  'involved/vbd',
#  'persons/nns',
#  'who/wps',
#  'had/hvd',
#  'been/ben',
#  'subpenaed/vbn',
#  ',/,',
#  'he/pps',
#  'would/md',
#  'dismiss/vb',
#  'them/ppo',
#  './.',
#  'Washington/np-hl',
#  ',/,-hl',
#  'Feb./np-hl',
#  '9/cd-hl',
#  '--/--',
#  'President/nn-tl',
#  'Kennedy/np',
#  'today/nr',
#  'proposed/vbd',
#  'a/at',
#  'mammoth/jj',
#  'new/jj',
#  'medical/jj',
#  'care/nn',
#  'program/nn',
#  'whereby/wrb',
#  'social/jj',
#  'security/nn',
#  'taxes/nns',
#  'on/in',
#  '70/cd',
#  'million/cd',
#  'American/jj',
#  'workers/nns',
#  'would/md',
#  'be/be',
#  'raised/vbn',
#  'to/to',
#  'pay/vb',
#  'the/at',
#  'hospital/nn',
#  'and/cc',
#  'some/dti',
#  'other/ap',
#  'medical/jj',
#  'bills/nns',
#  'of/in',
#  '14.2/cd',
#  'million/cd',
#  'Americans/nps',
#  'over/in',
#  '65/cd',
#  'who/wps',
#  'are/ber',
#  'covered/vbn',
#  'by/in',
#  'social/jj',
#  'security/nn',
#  'or/cc',
#  'railroad/nn',
#  'retirement/nn',
#  'programs/nns',
#  './.',
#  'The/at',
#  'President/nn-tl',
#  ',/,',
#  'in/in',
#  'a/at',
#  'special/jj',
#  'message/nn',
#  'to/in',
#  'Congress/np',
#  ',/,',
#  'tied/vbd',
#  'in/rp',
#  'with/in',
#  'his/pp$',
#  'aged/vbn',
#  'care/nn',
#  'plan/nn',
#  'requests/nns',
#  'for/in',
#  'large/jj',
#  'federal/jj',
#  'grants/nns',
#  'to/to',
#  'finance/vb',
#  'medical/jj',
#  'and/cc',
#  'dental/jj',
#  'scholarships/nns',
#  ',/,',
#  'build/vb',
#  '20/cd',
#  'new/jj',
#  'medical/jj',
#  'and/cc',
#  '20/cd',
#  'new/jj',
#  'dental/jj',
#  'schools/nns',
#  ',/,',
#  'and/cc',
#  'expand/vb',
#  'child/nn',
#  'health/nn',
#  'care/nn',
#  'and/cc',
#  'general/jj',
#  'medical/jj',
#  'research/nn',
#  './.',
#  'The/at',
#  'aged/vbn',
#  'care/nn',
#  'plan/nn',
#  ',/,',
#  'similar/jj',
#  'to/in',
#  'one/cd',
#  'the/at',
#  'President/nn-tl',
#  'sponsored/vbd',
#  'last/ap',
#  'year/nn',
#  'as/cs',
#  'a/at',
#  ...]

# %%
brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
brown.tagged_words(tagset='universal')[1:10]
# Out:
# [('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP')]

# %%
g.fileids()

moby_sample = g.fileids()[13]

moby_text = g.raw(moby_sample)

moby_tokens = word_tokenize(moby_text) # you can use split() here too

moby_tri  = nltk.trigrams(moby_tokens)

list(moby_tri)[0:10]
# Out:
# [('[', 'Moby', 'Dick'),
#  ('Moby', 'Dick', 'by'),
#  ('Dick', 'by', 'Herman'),
#  ('by', 'Herman', 'Melville'),
#  ('Herman', 'Melville', '1851'),
#  ('Melville', '1851', ']'),
#  ('1851', ']', 'ETYMOLOGY'),
#  (']', 'ETYMOLOGY', '.'),
#  ('ETYMOLOGY', '.', '('),
#  ('.', '(', 'Supplied')]

# %%
moby_ngrams  = nltk.ngrams(moby_tokens, 1) # Unigram
# list(moby_ngrams)

# Create a Frequency Distribution to view what words are in the text

# Apply a list of tokens to the FreqDist object
moby_dick_freqdist = FreqDist(moby_tokens)

# View the most frequent tokens and corresponding counts in descending order
moby_dick_freqdist.most_common(10)

# %%
# moby_dick_freqdist.tabulate()

moby_dick_freqdist.most_common()[0:10]
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7306),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2978)]

# %%
moby_tags = nltk.pos_tag(moby_tokens)
list(nltk.trigrams(moby_tags))
# Out:
# [(('[', 'JJ'), ('Moby', 'NNP'), ('Dick', 'NNP')),
#  (('Moby', 'NNP'), ('Dick', 'NNP'), ('by', 'IN')),
#  (('Dick', 'NNP'), ('by', 'IN'), ('Herman', 'NNP')),
#  (('by', 'IN'), ('Herman', 'NNP'), ('Melville', 'NNP')),
#  (('Herman', 'NNP'), ('Melville', 'NNP'), ('1851', 'CD')),
#  (('Melville', 'NNP'), ('1851', 'CD'), (']', 'NNP')),
#  (('1851', 'CD'), (']', 'NNP'), ('ETYMOLOGY', 'NNP')),
#  ((']', 'NNP'), ('ETYMOLOGY', 'NNP'), ('.', '.')),
#  (('ETYMOLOGY', 'NNP'), ('.', '.'), ('(', '(')),
#  (('.', '.'), ('(', '('), ('Supplied', 'VBN')),
#  (('(', '('), ('Supplied', 'VBN'), ('by', 'IN')),
#  (('Supplied', 'VBN'), ('by', 'IN'), ('a', 'DT')),
#  (('by', 'IN'), ('a', 'DT'), ('Late', 'JJ')),
#  (('a', 'DT'), ('Late', 'JJ'), ('Consumptive', 'NNP')),
#  (('Late', 'JJ'), ('Consumptive', 'NNP'), ('Usher', 'NNP')),
#  (('Consumptive', 'NNP'), ('Usher', 'NNP'), ('to', 'TO')),
#  (('Usher', 'NNP'), ('to', 'TO'), ('a', 'DT')),
#  (('to', 'TO'), ('a', 'DT'), ('Grammar', 'NNP')),
#  (('a', 'DT'), ('Grammar', 'NNP'), ('School', 'NNP')),
#  (('Grammar', 'NNP'), ('School', 'NNP'), (')', ')')),
#  (('School', 'NNP'), (')', ')'), ('The', 'DT')),
#  ((')', ')'), ('The', 'DT'), ('pale', 'NN')),
#  (('The', 'DT'), ('pale', 'NN'), ('Usher', 'NNP')),
#  (('pale', 'NN'), ('Usher', 'NNP'), ('--', ':')),
#  (('Usher', 'NNP'), ('--', ':'), ('threadbare', 'NN')),
#  (('--', ':'), ('threadbare', 'NN'), ('in', 'IN')),
#  (('threadbare', 'NN'), ('in', 'IN'), ('coat', 'NN')),
#  (('in', 'IN'), ('coat', 'NN'), (',', ',')),
#  (('coat', 'NN'), (',', ','), ('heart', 'NN')),
#  ((',', ','), ('heart', 'NN'), (',', ',')),
#  (('heart', 'NN'), (',', ','), ('body', 'NN')),
#  ((',', ','), ('body', 'NN'), (',', ',')),
#  (('body', 'NN'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('brain', 'NN')),
#  (('and', 'CC'), ('brain', 'NN'), (';', ':')),
#  (('brain', 'NN'), (';', ':'), ('I', 'PRP')),
#  ((';', ':'), ('I', 'PRP'), ('see', 'VBP')),
#  (('I', 'PRP'), ('see', 'VBP'), ('him', 'PRP')),
#  (('see', 'VBP'), ('him', 'PRP'), ('now', 'RB')),
#  (('him', 'PRP'), ('now', 'RB'), ('.', '.')),
#  (('now', 'RB'), ('.', '.'), ('He', 'PRP')),
#  (('.', '.'), ('He', 'PRP'), ('was', 'VBD')),
#  (('He', 'PRP'), ('was', 'VBD'), ('ever', 'RB')),
#  (('was', 'VBD'), ('ever', 'RB'), ('dusting', 'VBG')),
#  (('ever', 'RB'), ('dusting', 'VBG'), ('his', 'PRP$')),
#  (('dusting', 'VBG'), ('his', 'PRP$'), ('old', 'JJ')),
#  (('his', 'PRP$'), ('old', 'JJ'), ('lexicons', 'NNS')),
#  (('old', 'JJ'), ('lexicons', 'NNS'), ('and', 'CC')),
#  (('lexicons', 'NNS'), ('and', 'CC'), ('grammars', 'NNS')),
#  (('and', 'CC'), ('grammars', 'NNS'), (',', ',')),
#  (('grammars', 'NNS'), (',', ','), ('with', 'IN')),
#  ((',', ','), ('with', 'IN'), ('a', 'DT')),
#  (('with', 'IN'), ('a', 'DT'), ('queer', 'NN')),
#  (('a', 'DT'), ('queer', 'NN'), ('handkerchief', 'NN')),
#  (('queer', 'NN'), ('handkerchief', 'NN'), (',', ',')),
#  (('handkerchief', 'NN'), (',', ','), ('mockingly', 'RB')),
#  ((',', ','), ('mockingly', 'RB'), ('embellished', 'VBN')),
#  (('mockingly', 'RB'), ('embellished', 'VBN'), ('with', 'IN')),
#  (('embellished', 'VBN'), ('with', 'IN'), ('all', 'PDT')),
#  (('with', 'IN'), ('all', 'PDT'), ('the', 'DT')),
#  (('all', 'PDT'), ('the', 'DT'), ('gay', 'NN')),
#  (('the', 'DT'), ('gay', 'NN'), ('flags', 'NNS')),
#  (('gay', 'NN'), ('flags', 'NNS'), ('of', 'IN')),
#  (('flags', 'NNS'), ('of', 'IN'), ('all', 'PDT')),
#  (('of', 'IN'), ('all', 'PDT'), ('the', 'DT')),
#  (('all', 'PDT'), ('the', 'DT'), ('known', 'VBN')),
#  (('the', 'DT'), ('known', 'VBN'), ('nations', 'NNS')),
#  (('known', 'VBN'), ('nations', 'NNS'), ('of', 'IN')),
#  (('nations', 'NNS'), ('of', 'IN'), ('the', 'DT')),
#  (('of', 'IN'), ('the', 'DT'), ('world', 'NN')),
#  (('the', 'DT'), ('world', 'NN'), ('.', '.')),
#  (('world', 'NN'), ('.', '.'), ('He', 'PRP')),
#  (('.', '.'), ('He', 'PRP'), ('loved', 'VBD')),
#  (('He', 'PRP'), ('loved', 'VBD'), ('to', 'TO')),
#  (('loved', 'VBD'), ('to', 'TO'), ('dust', 'VB')),
#  (('to', 'TO'), ('dust', 'VB'), ('his', 'PRP$')),
#  (('dust', 'VB'), ('his', 'PRP$'), ('old', 'JJ')),
#  (('his', 'PRP$'), ('old', 'JJ'), ('grammars', 'NNS')),
#  (('old', 'JJ'), ('grammars', 'NNS'), (';', ':')),
#  (('grammars', 'NNS'), (';', ':'), ('it', 'PRP')),
#  ((';', ':'), ('it', 'PRP'), ('somehow', 'VBZ')),
#  (('it', 'PRP'), ('somehow', 'VBZ'), ('mildly', 'RB')),
#  (('somehow', 'VBZ'), ('mildly', 'RB'), ('reminded', 'VBD')),
#  (('mildly', 'RB'), ('reminded', 'VBD'), ('him', 'PRP')),
#  (('reminded', 'VBD'), ('him', 'PRP'), ('of', 'IN')),
#  (('him', 'PRP'), ('of', 'IN'), ('his', 'PRP$')),
#  (('of', 'IN'), ('his', 'PRP$'), ('mortality', 'NN')),
#  (('his', 'PRP$'), ('mortality', 'NN'), ('.', '.')),
#  (('mortality', 'NN'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('While', 'IN')),
#  (('``', '``'), ('While', 'IN'), ('you', 'PRP')),
#  (('While', 'IN'), ('you', 'PRP'), ('take', 'VBP')),
#  (('you', 'PRP'), ('take', 'VBP'), ('in', 'IN')),
#  (('take', 'VBP'), ('in', 'IN'), ('hand', 'NN')),
#  (('in', 'IN'), ('hand', 'NN'), ('to', 'TO')),
#  (('hand', 'NN'), ('to', 'TO'), ('school', 'NN')),
#  (('to', 'TO'), ('school', 'NN'), ('others', 'NNS')),
#  (('school', 'NN'), ('others', 'NNS'), (',', ',')),
#  (('others', 'NNS'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('to', 'TO')),
#  (('and', 'CC'), ('to', 'TO'), ('teach', 'VB')),
#  (('to', 'TO'), ('teach', 'VB'), ('them', 'PRP')),
#  (('teach', 'VB'), ('them', 'PRP'), ('by', 'IN')),
#  (('them', 'PRP'), ('by', 'IN'), ('what', 'WP')),
#  (('by', 'IN'), ('what', 'WP'), ('name', 'NN')),
#  (('what', 'WP'), ('name', 'NN'), ('a', 'DT')),
#  (('name', 'NN'), ('a', 'DT'), ('whale-fish', 'JJ')),
#  (('a', 'DT'), ('whale-fish', 'JJ'), ('is', 'VBZ')),
#  (('whale-fish', 'JJ'), ('is', 'VBZ'), ('to', 'TO')),
#  (('is', 'VBZ'), ('to', 'TO'), ('be', 'VB')),
#  (('to', 'TO'), ('be', 'VB'), ('called', 'VBN')),
#  (('be', 'VB'), ('called', 'VBN'), ('in', 'IN')),
#  (('called', 'VBN'), ('in', 'IN'), ('our', 'PRP$')),
#  (('in', 'IN'), ('our', 'PRP$'), ('tongue', 'NN')),
#  (('our', 'PRP$'), ('tongue', 'NN'), ('leaving', 'VBG')),
#  (('tongue', 'NN'), ('leaving', 'VBG'), ('out', 'RP')),
#  (('leaving', 'VBG'), ('out', 'RP'), (',', ',')),
#  (('out', 'RP'), (',', ','), ('through', 'IN')),
#  ((',', ','), ('through', 'IN'), ('ignorance', 'NN')),
#  (('through', 'IN'), ('ignorance', 'NN'), (',', ',')),
#  (('ignorance', 'NN'), (',', ','), ('the', 'DT')),
#  ((',', ','), ('the', 'DT'), ('letter', 'NN')),
#  (('the', 'DT'), ('letter', 'NN'), ('H', 'NNP')),
#  (('letter', 'NN'), ('H', 'NNP'), (',', ',')),
#  (('H', 'NNP'), (',', ','), ('which', 'WDT')),
#  ((',', ','), ('which', 'WDT'), ('almost', 'RB')),
#  (('which', 'WDT'), ('almost', 'RB'), ('alone', 'RB')),
#  (('almost', 'RB'), ('alone', 'RB'), ('maketh', 'VBZ')),
#  (('alone', 'RB'), ('maketh', 'VBZ'), ('the', 'DT')),
#  (('maketh', 'VBZ'), ('the', 'DT'), ('signification', 'NN')),
#  (('the', 'DT'), ('signification', 'NN'), ('of', 'IN')),
#  (('signification', 'NN'), ('of', 'IN'), ('the', 'DT')),
#  (('of', 'IN'), ('the', 'DT'), ('word', 'NN')),
#  (('the', 'DT'), ('word', 'NN'), (',', ',')),
#  (('word', 'NN'), (',', ','), ('you', 'PRP')),
#  ((',', ','), ('you', 'PRP'), ('deliver', 'VBP')),
#  (('you', 'PRP'), ('deliver', 'VBP'), ('that', 'DT')),
#  (('deliver', 'VBP'), ('that', 'DT'), ('which', 'WDT')),
#  (('that', 'DT'), ('which', 'WDT'), ('is', 'VBZ')),
#  (('which', 'WDT'), ('is', 'VBZ'), ('not', 'RB')),
#  (('is', 'VBZ'), ('not', 'RB'), ('true', 'JJ')),
#  (('not', 'RB'), ('true', 'JJ'), ('.', '.')),
#  (('true', 'JJ'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('HACKLUYT', 'NNP')),
#  (('--', ':'), ('HACKLUYT', 'NNP'), ("''", "''")),
#  (('HACKLUYT', 'NNP'), ("''", "''"), ('WHALE', 'NNP')),
#  (("''", "''"), ('WHALE', 'NNP'), ('.', '.')),
#  (('WHALE', 'NNP'), ('.', '.'), ('...', ':')),
#  (('.', '.'), ('...', ':'), ('Sw.', 'NNP')),
#  (('...', ':'), ('Sw.', 'NNP'), ('and', 'CC')),
#  (('Sw.', 'NNP'), ('and', 'CC'), ('Dan', 'NNP')),
#  (('and', 'CC'), ('Dan', 'NNP'), ('.', '.')),
#  (('Dan', 'NNP'), ('.', '.'), ('HVAL', 'NNP')),
#  (('.', '.'), ('HVAL', 'NNP'), ('.', '.')),
#  (('HVAL', 'NNP'), ('.', '.'), ('This', 'DT')),
#  (('.', '.'), ('This', 'DT'), ('animal', 'NN')),
#  (('This', 'DT'), ('animal', 'NN'), ('is', 'VBZ')),
#  (('animal', 'NN'), ('is', 'VBZ'), ('named', 'VBN')),
#  (('is', 'VBZ'), ('named', 'VBN'), ('from', 'IN')),
#  (('named', 'VBN'), ('from', 'IN'), ('roundness', 'NN')),
#  (('from', 'IN'), ('roundness', 'NN'), ('or', 'CC')),
#  (('roundness', 'NN'), ('or', 'CC'), ('rolling', 'NN')),
#  (('or', 'CC'), ('rolling', 'NN'), (';', ':')),
#  (('rolling', 'NN'), (';', ':'), ('for', 'IN')),
#  ((';', ':'), ('for', 'IN'), ('in', 'IN')),
#  (('for', 'IN'), ('in', 'IN'), ('Dan', 'NNP')),
#  (('in', 'IN'), ('Dan', 'NNP'), ('.', '.')),
#  (('Dan', 'NNP'), ('.', '.'), ('HVALT', 'NNP')),
#  (('.', '.'), ('HVALT', 'NNP'), ('is', 'VBZ')),
#  (('HVALT', 'NNP'), ('is', 'VBZ'), ('arched', 'VBN')),
#  (('is', 'VBZ'), ('arched', 'VBN'), ('or', 'CC')),
#  (('arched', 'VBN'), ('or', 'CC'), ('vaulted', 'VBN')),
#  (('or', 'CC'), ('vaulted', 'VBN'), ('.', '.')),
#  (('vaulted', 'VBN'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ("WEBSTER'S", 'NNP')),
#  (('--', ':'), ("WEBSTER'S", 'NNP'), ('DICTIONARY', 'NNP')),
#  (("WEBSTER'S", 'NNP'), ('DICTIONARY', 'NNP'), ("''", "''")),
#  (('DICTIONARY', 'NNP'), ("''", "''"), ('WHALE', 'NNP')),
#  (("''", "''"), ('WHALE', 'NNP'), ('.', '.')),
#  (('WHALE', 'NNP'), ('.', '.'), ('...', ':')),
#  (('.', '.'), ('...', ':'), ('It', 'PRP')),
#  (('...', ':'), ('It', 'PRP'), ('is', 'VBZ')),
#  (('It', 'PRP'), ('is', 'VBZ'), ('more', 'RBR')),
#  (('is', 'VBZ'), ('more', 'RBR'), ('immediately', 'RB')),
#  (('more', 'RBR'), ('immediately', 'RB'), ('from', 'IN')),
#  (('immediately', 'RB'), ('from', 'IN'), ('the', 'DT')),
#  (('from', 'IN'), ('the', 'DT'), ('Dut', 'NNP')),
#  (('the', 'DT'), ('Dut', 'NNP'), ('.', '.')),
#  (('Dut', 'NNP'), ('.', '.'), ('and', 'CC')),
#  (('.', '.'), ('and', 'CC'), ('Ger', 'NNP')),
#  (('and', 'CC'), ('Ger', 'NNP'), ('.', '.')),
#  (('Ger', 'NNP'), ('.', '.'), ('WALLEN', 'NNP')),
#  (('.', '.'), ('WALLEN', 'NNP'), (';', ':')),
#  (('WALLEN', 'NNP'), (';', ':'), ('A.S.', 'NNP')),
#  ((';', ':'), ('A.S.', 'NNP'), ('WALW-IAN', 'NNP')),
#  (('A.S.', 'NNP'), ('WALW-IAN', 'NNP'), (',', ',')),
#  (('WALW-IAN', 'NNP'), (',', ','), ('to', 'TO')),
#  ((',', ','), ('to', 'TO'), ('roll', 'VB')),
#  (('to', 'TO'), ('roll', 'VB'), (',', ',')),
#  (('roll', 'VB'), (',', ','), ('to', 'TO')),
#  ((',', ','), ('to', 'TO'), ('wallow', 'VB')),
#  (('to', 'TO'), ('wallow', 'VB'), ('.', '.')),
#  (('wallow', 'VB'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('RICHARDSON', 'NNP')),
#  (('--', ':'), ('RICHARDSON', 'NNP'), ("'S", 'POS')),
#  (('RICHARDSON', 'NNP'), ("'S", 'POS'), ('DICTIONARY', 'NNP')),
#  (("'S", 'POS'), ('DICTIONARY', 'NNP'), ('KETOS', 'NNP')),
#  (('DICTIONARY', 'NNP'), ('KETOS', 'NNP'), (',', ',')),
#  (('KETOS', 'NNP'), (',', ','), ('GREEK', 'NNP')),
#  ((',', ','), ('GREEK', 'NNP'), ('.', '.')),
#  (('GREEK', 'NNP'), ('.', '.'), ('CETUS', 'NNP')),
#  (('.', '.'), ('CETUS', 'NNP'), (',', ',')),
#  (('CETUS', 'NNP'), (',', ','), ('LATIN', 'NNP')),
#  ((',', ','), ('LATIN', 'NNP'), ('.', '.')),
#  (('LATIN', 'NNP'), ('.', '.'), ('WHOEL', 'NNP')),
#  (('.', '.'), ('WHOEL', 'NNP'), (',', ',')),
#  (('WHOEL', 'NNP'), (',', ','), ('ANGLO-SAXON', 'NNP')),
#  ((',', ','), ('ANGLO-SAXON', 'NNP'), ('.', '.')),
#  (('ANGLO-SAXON', 'NNP'), ('.', '.'), ('HVALT', 'NNP')),
#  (('.', '.'), ('HVALT', 'NNP'), (',', ',')),
#  (('HVALT', 'NNP'), (',', ','), ('DANISH', 'NNP')),
#  ((',', ','), ('DANISH', 'NNP'), ('.', '.')),
#  (('DANISH', 'NNP'), ('.', '.'), ('WAL', 'NNP')),
#  (('.', '.'), ('WAL', 'NNP'), (',', ',')),
#  (('WAL', 'NNP'), (',', ','), ('DUTCH', 'NNP')),
#  ((',', ','), ('DUTCH', 'NNP'), ('.', '.')),
#  (('DUTCH', 'NNP'), ('.', '.'), ('HWAL', 'NNP')),
#  (('.', '.'), ('HWAL', 'NNP'), (',', ',')),
#  (('HWAL', 'NNP'), (',', ','), ('SWEDISH', 'NNP')),
#  ((',', ','), ('SWEDISH', 'NNP'), ('.', '.')),
#  (('SWEDISH', 'NNP'), ('.', '.'), ('WHALE', 'NNP')),
#  (('.', '.'), ('WHALE', 'NNP'), (',', ',')),
#  (('WHALE', 'NNP'), (',', ','), ('ICELANDIC', 'NNP')),
#  ((',', ','), ('ICELANDIC', 'NNP'), ('.', '.')),
#  (('ICELANDIC', 'NNP'), ('.', '.'), ('WHALE', 'NNP')),
#  (('.', '.'), ('WHALE', 'NNP'), (',', ',')),
#  (('WHALE', 'NNP'), (',', ','), ('ENGLISH', 'NNP')),
#  ((',', ','), ('ENGLISH', 'NNP'), ('.', '.')),
#  (('ENGLISH', 'NNP'), ('.', '.'), ('BALEINE', 'NNP')),
#  (('.', '.'), ('BALEINE', 'NNP'), (',', ',')),
#  (('BALEINE', 'NNP'), (',', ','), ('FRENCH', 'NNP')),
#  ((',', ','), ('FRENCH', 'NNP'), ('.', '.')),
#  (('FRENCH', 'NNP'), ('.', '.'), ('BALLENA', 'NNP')),
#  (('.', '.'), ('BALLENA', 'NNP'), (',', ',')),
#  (('BALLENA', 'NNP'), (',', ','), ('SPANISH', 'NNP')),
#  ((',', ','), ('SPANISH', 'NNP'), ('.', '.')),
#  (('SPANISH', 'NNP'), ('.', '.'), ('PEKEE-NUEE-NUEE', 'NNP')),
#  (('.', '.'), ('PEKEE-NUEE-NUEE', 'NNP'), (',', ',')),
#  (('PEKEE-NUEE-NUEE', 'NNP'), (',', ','), ('FEGEE', 'NNP')),
#  ((',', ','), ('FEGEE', 'NNP'), ('.', '.')),
#  (('FEGEE', 'NNP'), ('.', '.'), ('PEKEE-NUEE-NUEE', 'NNP')),
#  (('.', '.'), ('PEKEE-NUEE-NUEE', 'NNP'), (',', ',')),
#  (('PEKEE-NUEE-NUEE', 'NNP'), (',', ','), ('ERROMANGOAN', 'NNP')),
#  ((',', ','), ('ERROMANGOAN', 'NNP'), ('.', '.')),
#  (('ERROMANGOAN', 'NNP'), ('.', '.'), ('EXTRACTS', 'NNP')),
#  (('.', '.'), ('EXTRACTS', 'NNP'), ('(', '(')),
#  (('EXTRACTS', 'NNP'), ('(', '('), ('Supplied', 'VBN')),
#  (('(', '('), ('Supplied', 'VBN'), ('by', 'IN')),
#  (('Supplied', 'VBN'), ('by', 'IN'), ('a', 'DT')),
#  (('by', 'IN'), ('a', 'DT'), ('Sub-Sub-Librarian', 'JJ')),
#  (('a', 'DT'), ('Sub-Sub-Librarian', 'JJ'), (')', ')')),
#  (('Sub-Sub-Librarian', 'JJ'), (')', ')'), ('.', '.')),
#  ((')', ')'), ('.', '.'), ('It', 'PRP')),
#  (('.', '.'), ('It', 'PRP'), ('will', 'MD')),
#  (('It', 'PRP'), ('will', 'MD'), ('be', 'VB')),
#  (('will', 'MD'), ('be', 'VB'), ('seen', 'VBN')),
#  (('be', 'VB'), ('seen', 'VBN'), ('that', 'IN')),
#  (('seen', 'VBN'), ('that', 'IN'), ('this', 'DT')),
#  (('that', 'IN'), ('this', 'DT'), ('mere', 'JJ')),
#  (('this', 'DT'), ('mere', 'JJ'), ('painstaking', 'VBG')),
#  (('mere', 'JJ'), ('painstaking', 'VBG'), ('burrower', 'NN')),
#  (('painstaking', 'VBG'), ('burrower', 'NN'), ('and', 'CC')),
#  (('burrower', 'NN'), ('and', 'CC'), ('grub-worm', 'NN')),
#  (('and', 'CC'), ('grub-worm', 'NN'), ('of', 'IN')),
#  (('grub-worm', 'NN'), ('of', 'IN'), ('a', 'DT')),
#  (('of', 'IN'), ('a', 'DT'), ('poor', 'JJ')),
#  (('a', 'DT'), ('poor', 'JJ'), ('devil', 'NN')),
#  (('poor', 'JJ'), ('devil', 'NN'), ('of', 'IN')),
#  (('devil', 'NN'), ('of', 'IN'), ('a', 'DT')),
#  (('of', 'IN'), ('a', 'DT'), ('Sub-Sub', 'JJ')),
#  (('a', 'DT'), ('Sub-Sub', 'JJ'), ('appears', 'VBZ')),
#  (('Sub-Sub', 'JJ'), ('appears', 'VBZ'), ('to', 'TO')),
#  (('appears', 'VBZ'), ('to', 'TO'), ('have', 'VB')),
#  (('to', 'TO'), ('have', 'VB'), ('gone', 'VBN')),
#  (('have', 'VB'), ('gone', 'VBN'), ('through', 'IN')),
#  (('gone', 'VBN'), ('through', 'IN'), ('the', 'DT')),
#  (('through', 'IN'), ('the', 'DT'), ('long', 'JJ')),
#  (('the', 'DT'), ('long', 'JJ'), ('Vaticans', 'NNPS')),
#  (('long', 'JJ'), ('Vaticans', 'NNPS'), ('and', 'CC')),
#  (('Vaticans', 'NNPS'), ('and', 'CC'), ('street-stalls', 'NNS')),
#  (('and', 'CC'), ('street-stalls', 'NNS'), ('of', 'IN')),
#  (('street-stalls', 'NNS'), ('of', 'IN'), ('the', 'DT')),
#  (('of', 'IN'), ('the', 'DT'), ('earth', 'NN')),
#  (('the', 'DT'), ('earth', 'NN'), (',', ',')),
#  (('earth', 'NN'), (',', ','), ('picking', 'VBG')),
#  ((',', ','), ('picking', 'VBG'), ('up', 'RP')),
#  (('picking', 'VBG'), ('up', 'RP'), ('whatever', 'WDT')),
#  (('up', 'RP'), ('whatever', 'WDT'), ('random', 'JJ')),
#  (('whatever', 'WDT'), ('random', 'JJ'), ('allusions', 'NNS')),
#  (('random', 'JJ'), ('allusions', 'NNS'), ('to', 'TO')),
#  (('allusions', 'NNS'), ('to', 'TO'), ('whales', 'NNS')),
#  (('to', 'TO'), ('whales', 'NNS'), ('he', 'PRP')),
#  (('whales', 'NNS'), ('he', 'PRP'), ('could', 'MD')),
#  (('he', 'PRP'), ('could', 'MD'), ('anyways', 'VB')),
#  (('could', 'MD'), ('anyways', 'VB'), ('find', 'VB')),
#  (('anyways', 'VB'), ('find', 'VB'), ('in', 'IN')),
#  (('find', 'VB'), ('in', 'IN'), ('any', 'DT')),
#  (('in', 'IN'), ('any', 'DT'), ('book', 'NN')),
#  (('any', 'DT'), ('book', 'NN'), ('whatsoever', 'NN')),
#  (('book', 'NN'), ('whatsoever', 'NN'), (',', ',')),
#  (('whatsoever', 'NN'), (',', ','), ('sacred', 'VBD')),
#  ((',', ','), ('sacred', 'VBD'), ('or', 'CC')),
#  (('sacred', 'VBD'), ('or', 'CC'), ('profane', 'NN')),
#  (('or', 'CC'), ('profane', 'NN'), ('.', '.')),
#  (('profane', 'NN'), ('.', '.'), ('Therefore', 'IN')),
#  (('.', '.'), ('Therefore', 'IN'), ('you', 'PRP')),
#  (('Therefore', 'IN'), ('you', 'PRP'), ('must', 'MD')),
#  (('you', 'PRP'), ('must', 'MD'), ('not', 'RB')),
#  (('must', 'MD'), ('not', 'RB'), (',', ',')),
#  (('not', 'RB'), (',', ','), ('in', 'IN')),
#  ((',', ','), ('in', 'IN'), ('every', 'DT')),
#  (('in', 'IN'), ('every', 'DT'), ('case', 'NN')),
#  (('every', 'DT'), ('case', 'NN'), ('at', 'IN')),
#  (('case', 'NN'), ('at', 'IN'), ('least', 'JJS')),
#  (('at', 'IN'), ('least', 'JJS'), (',', ',')),
#  (('least', 'JJS'), (',', ','), ('take', 'VB')),
#  ((',', ','), ('take', 'VB'), ('the', 'DT')),
#  (('take', 'VB'), ('the', 'DT'), ('higgledy-piggledy', 'JJ')),
#  (('the', 'DT'), ('higgledy-piggledy', 'JJ'), ('whale', 'NN')),
#  (('higgledy-piggledy', 'JJ'), ('whale', 'NN'), ('statements', 'NNS')),
#  (('whale', 'NN'), ('statements', 'NNS'), (',', ',')),
#  (('statements', 'NNS'), (',', ','), ('however', 'RB')),
#  ((',', ','), ('however', 'RB'), ('authentic', 'JJ')),
#  (('however', 'RB'), ('authentic', 'JJ'), (',', ',')),
#  (('authentic', 'JJ'), (',', ','), ('in', 'IN')),
#  ((',', ','), ('in', 'IN'), ('these', 'DT')),
#  (('in', 'IN'), ('these', 'DT'), ('extracts', 'NNS')),
#  (('these', 'DT'), ('extracts', 'NNS'), (',', ',')),
#  (('extracts', 'NNS'), (',', ','), ('for', 'IN')),
#  ((',', ','), ('for', 'IN'), ('veritable', 'JJ')),
#  (('for', 'IN'), ('veritable', 'JJ'), ('gospel', 'JJ')),
#  (('veritable', 'JJ'), ('gospel', 'JJ'), ('cetology', 'NN')),
#  (('gospel', 'JJ'), ('cetology', 'NN'), ('.', '.')),
#  (('cetology', 'NN'), ('.', '.'), ('Far', 'CD')),
#  (('.', '.'), ('Far', 'CD'), ('from', 'IN')),
#  (('Far', 'CD'), ('from', 'IN'), ('it', 'PRP')),
#  (('from', 'IN'), ('it', 'PRP'), ('.', '.')),
#  (('it', 'PRP'), ('.', '.'), ('As', 'IN')),
#  (('.', '.'), ('As', 'IN'), ('touching', 'VBG')),
#  (('As', 'IN'), ('touching', 'VBG'), ('the', 'DT')),
#  (('touching', 'VBG'), ('the', 'DT'), ('ancient', 'NN')),
#  (('the', 'DT'), ('ancient', 'NN'), ('authors', 'NNS')),
#  (('ancient', 'NN'), ('authors', 'NNS'), ('generally', 'RB')),
#  (('authors', 'NNS'), ('generally', 'RB'), (',', ',')),
#  (('generally', 'RB'), (',', ','), ('as', 'RB')),
#  ((',', ','), ('as', 'RB'), ('well', 'RB')),
#  (('as', 'RB'), ('well', 'RB'), ('as', 'IN')),
#  (('well', 'RB'), ('as', 'IN'), ('the', 'DT')),
#  (('as', 'IN'), ('the', 'DT'), ('poets', 'NNS')),
#  (('the', 'DT'), ('poets', 'NNS'), ('here', 'RB')),
#  (('poets', 'NNS'), ('here', 'RB'), ('appearing', 'VBG')),
#  (('here', 'RB'), ('appearing', 'VBG'), (',', ',')),
#  (('appearing', 'VBG'), (',', ','), ('these', 'DT')),
#  ((',', ','), ('these', 'DT'), ('extracts', 'NNS')),
#  (('these', 'DT'), ('extracts', 'NNS'), ('are', 'VBP')),
#  (('extracts', 'NNS'), ('are', 'VBP'), ('solely', 'RB')),
#  (('are', 'VBP'), ('solely', 'RB'), ('valuable', 'JJ')),
#  (('solely', 'RB'), ('valuable', 'JJ'), ('or', 'CC')),
#  (('valuable', 'JJ'), ('or', 'CC'), ('entertaining', 'JJ')),
#  (('or', 'CC'), ('entertaining', 'JJ'), (',', ',')),
#  (('entertaining', 'JJ'), (',', ','), ('as', 'IN')),
#  ((',', ','), ('as', 'IN'), ('affording', 'VBG')),
#  (('as', 'IN'), ('affording', 'VBG'), ('a', 'DT')),
#  (('affording', 'VBG'), ('a', 'DT'), ('glancing', 'VBG')),
#  (('a', 'DT'), ('glancing', 'VBG'), ('bird', 'NN')),
#  (('glancing', 'VBG'), ('bird', 'NN'), ("'s", 'POS')),
#  (('bird', 'NN'), ("'s", 'POS'), ('eye', 'NN')),
#  (("'s", 'POS'), ('eye', 'NN'), ('view', 'NN')),
#  (('eye', 'NN'), ('view', 'NN'), ('of', 'IN')),
#  (('view', 'NN'), ('of', 'IN'), ('what', 'WP')),
#  (('of', 'IN'), ('what', 'WP'), ('has', 'VBZ')),
#  (('what', 'WP'), ('has', 'VBZ'), ('been', 'VBN')),
#  (('has', 'VBZ'), ('been', 'VBN'), ('promiscuously', 'RB')),
#  (('been', 'VBN'), ('promiscuously', 'RB'), ('said', 'VBD')),
#  (('promiscuously', 'RB'), ('said', 'VBD'), (',', ',')),
#  (('said', 'VBD'), (',', ','), ('thought', 'VBD')),
#  ((',', ','), ('thought', 'VBD'), (',', ',')),
#  (('thought', 'VBD'), (',', ','), ('fancied', 'VBN')),
#  ((',', ','), ('fancied', 'VBN'), (',', ',')),
#  (('fancied', 'VBN'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('sung', 'NN')),
#  (('and', 'CC'), ('sung', 'NN'), ('of', 'IN')),
#  (('sung', 'NN'), ('of', 'IN'), ('Leviathan', 'NNP')),
#  (('of', 'IN'), ('Leviathan', 'NNP'), (',', ',')),
#  (('Leviathan', 'NNP'), (',', ','), ('by', 'IN')),
#  ((',', ','), ('by', 'IN'), ('many', 'JJ')),
#  (('by', 'IN'), ('many', 'JJ'), ('nations', 'NNS')),
#  (('many', 'JJ'), ('nations', 'NNS'), ('and', 'CC')),
#  (('nations', 'NNS'), ('and', 'CC'), ('generations', 'NNS')),
#  (('and', 'CC'), ('generations', 'NNS'), (',', ',')),
#  (('generations', 'NNS'), (',', ','), ('including', 'VBG')),
#  ((',', ','), ('including', 'VBG'), ('our', 'PRP$')),
#  (('including', 'VBG'), ('our', 'PRP$'), ('own', 'JJ')),
#  (('our', 'PRP$'), ('own', 'JJ'), ('.', '.')),
#  (('own', 'JJ'), ('.', '.'), ('So', 'CC')),
#  (('.', '.'), ('So', 'CC'), ('fare', 'JJ')),
#  (('So', 'CC'), ('fare', 'JJ'), ('thee', 'NN')),
#  (('fare', 'JJ'), ('thee', 'NN'), ('well', 'RB')),
#  (('thee', 'NN'), ('well', 'RB'), (',', ',')),
#  (('well', 'RB'), (',', ','), ('poor', 'JJ')),
#  ((',', ','), ('poor', 'JJ'), ('devil', 'NN')),
#  (('poor', 'JJ'), ('devil', 'NN'), ('of', 'IN')),
#  (('devil', 'NN'), ('of', 'IN'), ('a', 'DT')),
#  (('of', 'IN'), ('a', 'DT'), ('Sub-Sub', 'NNP')),
#  (('a', 'DT'), ('Sub-Sub', 'NNP'), (',', ',')),
#  (('Sub-Sub', 'NNP'), (',', ','), ('whose', 'WP$')),
#  ((',', ','), ('whose', 'WP$'), ('commentator', 'NN')),
#  (('whose', 'WP$'), ('commentator', 'NN'), ('I', 'PRP')),
#  (('commentator', 'NN'), ('I', 'PRP'), ('am', 'VBP')),
#  (('I', 'PRP'), ('am', 'VBP'), ('.', '.')),
#  (('am', 'VBP'), ('.', '.'), ('Thou', 'NNP')),
#  (('.', '.'), ('Thou', 'NNP'), ('belongest', 'JJS')),
#  (('Thou', 'NNP'), ('belongest', 'JJS'), ('to', 'TO')),
#  (('belongest', 'JJS'), ('to', 'TO'), ('that', 'DT')),
#  (('to', 'TO'), ('that', 'DT'), ('hopeless', 'NN')),
#  (('that', 'DT'), ('hopeless', 'NN'), (',', ',')),
#  (('hopeless', 'NN'), (',', ','), ('sallow', 'NN')),
#  ((',', ','), ('sallow', 'NN'), ('tribe', 'NN')),
#  (('sallow', 'NN'), ('tribe', 'NN'), ('which', 'WDT')),
#  (('tribe', 'NN'), ('which', 'WDT'), ('no', 'DT')),
#  (('which', 'WDT'), ('no', 'DT'), ('wine', 'NN')),
#  (('no', 'DT'), ('wine', 'NN'), ('of', 'IN')),
#  (('wine', 'NN'), ('of', 'IN'), ('this', 'DT')),
#  (('of', 'IN'), ('this', 'DT'), ('world', 'NN')),
#  (('this', 'DT'), ('world', 'NN'), ('will', 'MD')),
#  (('world', 'NN'), ('will', 'MD'), ('ever', 'RB')),
#  (('will', 'MD'), ('ever', 'RB'), ('warm', 'VB')),
#  (('ever', 'RB'), ('warm', 'VB'), (';', ':')),
#  (('warm', 'VB'), (';', ':'), ('and', 'CC')),
#  ((';', ':'), ('and', 'CC'), ('for', 'IN')),
#  (('and', 'CC'), ('for', 'IN'), ('whom', 'WP')),
#  (('for', 'IN'), ('whom', 'WP'), ('even', 'RB')),
#  (('whom', 'WP'), ('even', 'RB'), ('Pale', 'NNP')),
#  (('even', 'RB'), ('Pale', 'NNP'), ('Sherry', 'NNP')),
#  (('Pale', 'NNP'), ('Sherry', 'NNP'), ('would', 'MD')),
#  (('Sherry', 'NNP'), ('would', 'MD'), ('be', 'VB')),
#  (('would', 'MD'), ('be', 'VB'), ('too', 'RB')),
#  (('be', 'VB'), ('too', 'RB'), ('rosy-strong', 'JJ')),
#  (('too', 'RB'), ('rosy-strong', 'JJ'), (';', ':')),
#  (('rosy-strong', 'JJ'), (';', ':'), ('but', 'CC')),
#  ((';', ':'), ('but', 'CC'), ('with', 'IN')),
#  (('but', 'CC'), ('with', 'IN'), ('whom', 'WP')),
#  (('with', 'IN'), ('whom', 'WP'), ('one', 'CD')),
#  (('whom', 'WP'), ('one', 'CD'), ('sometimes', 'VBZ')),
#  (('one', 'CD'), ('sometimes', 'VBZ'), ('loves', 'VBZ')),
#  (('sometimes', 'VBZ'), ('loves', 'VBZ'), ('to', 'TO')),
#  (('loves', 'VBZ'), ('to', 'TO'), ('sit', 'VB')),
#  (('to', 'TO'), ('sit', 'VB'), (',', ',')),
#  (('sit', 'VB'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('feel', 'VB')),
#  (('and', 'CC'), ('feel', 'VB'), ('poor-devilish', 'JJ')),
#  (('feel', 'VB'), ('poor-devilish', 'JJ'), (',', ',')),
#  (('poor-devilish', 'JJ'), (',', ','), ('too', 'RB')),
#  ((',', ','), ('too', 'RB'), (';', ':')),
#  (('too', 'RB'), (';', ':'), ('and', 'CC')),
#  ((';', ':'), ('and', 'CC'), ('grow', 'VB')),
#  (('and', 'CC'), ('grow', 'VB'), ('convivial', 'JJ')),
#  (('grow', 'VB'), ('convivial', 'JJ'), ('upon', 'IN')),
#  (('convivial', 'JJ'), ('upon', 'IN'), ('tears', 'NNS')),
#  (('upon', 'IN'), ('tears', 'NNS'), (';', ':')),
#  (('tears', 'NNS'), (';', ':'), ('and', 'CC')),
#  ((';', ':'), ('and', 'CC'), ('say', 'VB')),
#  (('and', 'CC'), ('say', 'VB'), ('to', 'TO')),
#  (('say', 'VB'), ('to', 'TO'), ('them', 'PRP')),
#  (('to', 'TO'), ('them', 'PRP'), ('bluntly', 'RB')),
#  (('them', 'PRP'), ('bluntly', 'RB'), (',', ',')),
#  (('bluntly', 'RB'), (',', ','), ('with', 'IN')),
#  ((',', ','), ('with', 'IN'), ('full', 'JJ')),
#  (('with', 'IN'), ('full', 'JJ'), ('eyes', 'NNS')),
#  (('full', 'JJ'), ('eyes', 'NNS'), ('and', 'CC')),
#  (('eyes', 'NNS'), ('and', 'CC'), ('empty', 'JJ')),
#  (('and', 'CC'), ('empty', 'JJ'), ('glasses', 'NNS')),
#  (('empty', 'JJ'), ('glasses', 'NNS'), (',', ',')),
#  (('glasses', 'NNS'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('in', 'IN')),
#  (('and', 'CC'), ('in', 'IN'), ('not', 'RB')),
#  (('in', 'IN'), ('not', 'RB'), ('altogether', 'RB')),
#  (('not', 'RB'), ('altogether', 'RB'), ('unpleasant', 'JJ')),
#  (('altogether', 'RB'), ('unpleasant', 'JJ'), ('sadness', 'NN')),
#  (('unpleasant', 'JJ'), ('sadness', 'NN'), ('--', ':')),
#  (('sadness', 'NN'), ('--', ':'), ('Give', 'VB')),
#  (('--', ':'), ('Give', 'VB'), ('it', 'PRP')),
#  (('Give', 'VB'), ('it', 'PRP'), ('up', 'RP')),
#  (('it', 'PRP'), ('up', 'RP'), (',', ',')),
#  (('up', 'RP'), (',', ','), ('Sub-Subs', 'JJ')),
#  ((',', ','), ('Sub-Subs', 'JJ'), ('!', '.')),
#  (('Sub-Subs', 'JJ'), ('!', '.'), ('For', 'IN')),
#  (('!', '.'), ('For', 'IN'), ('by', 'IN')),
#  (('For', 'IN'), ('by', 'IN'), ('how', 'WRB')),
#  (('by', 'IN'), ('how', 'WRB'), ('much', 'JJ')),
#  (('how', 'WRB'), ('much', 'JJ'), ('the', 'DT')),
#  (('much', 'JJ'), ('the', 'DT'), ('more', 'RBR')),
#  (('the', 'DT'), ('more', 'RBR'), ('pains', 'NNS')),
#  (('more', 'RBR'), ('pains', 'NNS'), ('ye', 'RB')),
#  (('pains', 'NNS'), ('ye', 'RB'), ('take', 'VBP')),
#  (('ye', 'RB'), ('take', 'VBP'), ('to', 'TO')),
#  (('take', 'VBP'), ('to', 'TO'), ('please', 'VB')),
#  (('to', 'TO'), ('please', 'VB'), ('the', 'DT')),
#  (('please', 'VB'), ('the', 'DT'), ('world', 'NN')),
#  (('the', 'DT'), ('world', 'NN'), (',', ',')),
#  (('world', 'NN'), (',', ','), ('by', 'IN')),
#  ((',', ','), ('by', 'IN'), ('so', 'RB')),
#  (('by', 'IN'), ('so', 'RB'), ('much', 'JJ')),
#  (('so', 'RB'), ('much', 'JJ'), ('the', 'DT')),
#  (('much', 'JJ'), ('the', 'DT'), ('more', 'RBR')),
#  (('the', 'DT'), ('more', 'RBR'), ('shall', 'MD')),
#  (('more', 'RBR'), ('shall', 'MD'), ('ye', 'VB')),
#  (('shall', 'MD'), ('ye', 'VB'), ('for', 'IN')),
#  (('ye', 'VB'), ('for', 'IN'), ('ever', 'RB')),
#  (('for', 'IN'), ('ever', 'RB'), ('go', 'VB')),
#  (('ever', 'RB'), ('go', 'VB'), ('thankless', 'NN')),
#  (('go', 'VB'), ('thankless', 'NN'), ('!', '.')),
#  (('thankless', 'NN'), ('!', '.'), ('Would', 'MD')),
#  (('!', '.'), ('Would', 'MD'), ('that', 'IN')),
#  (('Would', 'MD'), ('that', 'IN'), ('I', 'PRP')),
#  (('that', 'IN'), ('I', 'PRP'), ('could', 'MD')),
#  (('I', 'PRP'), ('could', 'MD'), ('clear', 'VB')),
#  (('could', 'MD'), ('clear', 'VB'), ('out', 'RP')),
#  (('clear', 'VB'), ('out', 'RP'), ('Hampton', 'NNP')),
#  (('out', 'RP'), ('Hampton', 'NNP'), ('Court', 'NNP')),
#  (('Hampton', 'NNP'), ('Court', 'NNP'), ('and', 'CC')),
#  (('Court', 'NNP'), ('and', 'CC'), ('the', 'DT')),
#  (('and', 'CC'), ('the', 'DT'), ('Tuileries', 'NNPS')),
#  (('the', 'DT'), ('Tuileries', 'NNPS'), ('for', 'IN')),
#  (('Tuileries', 'NNPS'), ('for', 'IN'), ('ye', 'NN')),
#  (('for', 'IN'), ('ye', 'NN'), ('!', '.')),
#  (('ye', 'NN'), ('!', '.'), ('But', 'CC')),
#  (('!', '.'), ('But', 'CC'), ('gulp', 'VBP')),
#  (('But', 'CC'), ('gulp', 'VBP'), ('down', 'RP')),
#  (('gulp', 'VBP'), ('down', 'RP'), ('your', 'PRP$')),
#  (('down', 'RP'), ('your', 'PRP$'), ('tears', 'NNS')),
#  (('your', 'PRP$'), ('tears', 'NNS'), ('and', 'CC')),
#  (('tears', 'NNS'), ('and', 'CC'), ('hie', 'NN')),
#  (('and', 'CC'), ('hie', 'NN'), ('aloft', 'RB')),
#  (('hie', 'NN'), ('aloft', 'RB'), ('to', 'TO')),
#  (('aloft', 'RB'), ('to', 'TO'), ('the', 'DT')),
#  (('to', 'TO'), ('the', 'DT'), ('royal-mast', 'JJ')),
#  (('the', 'DT'), ('royal-mast', 'JJ'), ('with', 'IN')),
#  (('royal-mast', 'JJ'), ('with', 'IN'), ('your', 'PRP$')),
#  (('with', 'IN'), ('your', 'PRP$'), ('hearts', 'NNS')),
#  (('your', 'PRP$'), ('hearts', 'NNS'), (';', ':')),
#  (('hearts', 'NNS'), (';', ':'), ('for', 'IN')),
#  ((';', ':'), ('for', 'IN'), ('your', 'PRP$')),
#  (('for', 'IN'), ('your', 'PRP$'), ('friends', 'NNS')),
#  (('your', 'PRP$'), ('friends', 'NNS'), ('who', 'WP')),
#  (('friends', 'NNS'), ('who', 'WP'), ('have', 'VBP')),
#  (('who', 'WP'), ('have', 'VBP'), ('gone', 'VBN')),
#  (('have', 'VBP'), ('gone', 'VBN'), ('before', 'RB')),
#  (('gone', 'VBN'), ('before', 'RB'), ('are', 'VBP')),
#  (('before', 'RB'), ('are', 'VBP'), ('clearing', 'VBG')),
#  (('are', 'VBP'), ('clearing', 'VBG'), ('out', 'RP')),
#  (('clearing', 'VBG'), ('out', 'RP'), ('the', 'DT')),
#  (('out', 'RP'), ('the', 'DT'), ('seven-storied', 'JJ')),
#  (('the', 'DT'), ('seven-storied', 'JJ'), ('heavens', 'NNS')),
#  (('seven-storied', 'JJ'), ('heavens', 'NNS'), (',', ',')),
#  (('heavens', 'NNS'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('making', 'VBG')),
#  (('and', 'CC'), ('making', 'VBG'), ('refugees', 'NNS')),
#  (('making', 'VBG'), ('refugees', 'NNS'), ('of', 'IN')),
#  (('refugees', 'NNS'), ('of', 'IN'), ('long-pampered', 'JJ')),
#  (('of', 'IN'), ('long-pampered', 'JJ'), ('Gabriel', 'NNP')),
#  (('long-pampered', 'JJ'), ('Gabriel', 'NNP'), (',', ',')),
#  (('Gabriel', 'NNP'), (',', ','), ('Michael', 'NNP')),
#  ((',', ','), ('Michael', 'NNP'), (',', ',')),
#  (('Michael', 'NNP'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('Raphael', 'NNP')),
#  (('and', 'CC'), ('Raphael', 'NNP'), (',', ',')),
#  (('Raphael', 'NNP'), (',', ','), ('against', 'IN')),
#  ((',', ','), ('against', 'IN'), ('your', 'PRP$')),
#  (('against', 'IN'), ('your', 'PRP$'), ('coming', 'VBG')),
#  (('your', 'PRP$'), ('coming', 'VBG'), ('.', '.')),
#  (('coming', 'VBG'), ('.', '.'), ('Here', 'RB')),
#  (('.', '.'), ('Here', 'RB'), ('ye', 'JJ')),
#  (('Here', 'RB'), ('ye', 'JJ'), ('strike', 'NN')),
#  (('ye', 'JJ'), ('strike', 'NN'), ('but', 'CC')),
#  (('strike', 'NN'), ('but', 'CC'), ('splintered', 'VBD')),
#  (('but', 'CC'), ('splintered', 'VBD'), ('hearts', 'NNS')),
#  (('splintered', 'VBD'), ('hearts', 'NNS'), ('together', 'RB')),
#  (('hearts', 'NNS'), ('together', 'RB'), ('--', ':')),
#  (('together', 'RB'), ('--', ':'), ('there', 'RB')),
#  (('--', ':'), ('there', 'RB'), (',', ',')),
#  (('there', 'RB'), (',', ','), ('ye', 'PRP')),
#  ((',', ','), ('ye', 'PRP'), ('shall', 'MD')),
#  (('ye', 'PRP'), ('shall', 'MD'), ('strike', 'VB')),
#  (('shall', 'MD'), ('strike', 'VB'), ('unsplinterable', 'JJ')),
#  (('strike', 'VB'), ('unsplinterable', 'JJ'), ('glasses', 'NNS')),
#  (('unsplinterable', 'JJ'), ('glasses', 'NNS'), ('!', '.')),
#  (('glasses', 'NNS'), ('!', '.'), ('EXTRACTS', 'NNP')),
#  (('!', '.'), ('EXTRACTS', 'NNP'), ('.', '.')),
#  (('EXTRACTS', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('And', 'CC')),
#  (('``', '``'), ('And', 'CC'), ('God', 'NNP')),
#  (('And', 'CC'), ('God', 'NNP'), ('created', 'VBD')),
#  (('God', 'NNP'), ('created', 'VBD'), ('great', 'JJ')),
#  (('created', 'VBD'), ('great', 'JJ'), ('whales', 'NNS')),
#  (('great', 'JJ'), ('whales', 'NNS'), ('.', '.')),
#  (('whales', 'NNS'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('GENESIS', 'NNP')),
#  (('--', ':'), ('GENESIS', 'NNP'), ('.', '.')),
#  (('GENESIS', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('Leviathan', 'NNP')),
#  (('``', '``'), ('Leviathan', 'NNP'), ('maketh', 'VBZ')),
#  (('Leviathan', 'NNP'), ('maketh', 'VBZ'), ('a', 'DT')),
#  (('maketh', 'VBZ'), ('a', 'DT'), ('path', 'NN')),
#  (('a', 'DT'), ('path', 'NN'), ('to', 'TO')),
#  (('path', 'NN'), ('to', 'TO'), ('shine', 'VB')),
#  (('to', 'TO'), ('shine', 'VB'), ('after', 'IN')),
#  (('shine', 'VB'), ('after', 'IN'), ('him', 'PRP')),
#  (('after', 'IN'), ('him', 'PRP'), (';', ':')),
#  (('him', 'PRP'), (';', ':'), ('One', 'CD')),
#  ((';', ':'), ('One', 'CD'), ('would', 'MD')),
#  (('One', 'CD'), ('would', 'MD'), ('think', 'VB')),
#  (('would', 'MD'), ('think', 'VB'), ('the', 'DT')),
#  (('think', 'VB'), ('the', 'DT'), ('deep', 'NN')),
#  (('the', 'DT'), ('deep', 'NN'), ('to', 'TO')),
#  (('deep', 'NN'), ('to', 'TO'), ('be', 'VB')),
#  (('to', 'TO'), ('be', 'VB'), ('hoary', 'JJ')),
#  (('be', 'VB'), ('hoary', 'JJ'), ('.', '.')),
#  (('hoary', 'JJ'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('JOB', 'NNP')),
#  (('--', ':'), ('JOB', 'NNP'), ('.', '.')),
#  (('JOB', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('Now', 'RB')),
#  (('``', '``'), ('Now', 'RB'), ('the', 'DT')),
#  (('Now', 'RB'), ('the', 'DT'), ('Lord', 'NNP')),
#  (('the', 'DT'), ('Lord', 'NNP'), ('had', 'VBD')),
#  (('Lord', 'NNP'), ('had', 'VBD'), ('prepared', 'VBN')),
#  (('had', 'VBD'), ('prepared', 'VBN'), ('a', 'DT')),
#  (('prepared', 'VBN'), ('a', 'DT'), ('great', 'JJ')),
#  (('a', 'DT'), ('great', 'JJ'), ('fish', 'NN')),
#  (('great', 'JJ'), ('fish', 'NN'), ('to', 'TO')),
#  (('fish', 'NN'), ('to', 'TO'), ('swallow', 'VB')),
#  (('to', 'TO'), ('swallow', 'VB'), ('up', 'RP')),
#  (('swallow', 'VB'), ('up', 'RP'), ('Jonah', 'NNP')),
#  (('up', 'RP'), ('Jonah', 'NNP'), ('.', '.')),
#  (('Jonah', 'NNP'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('JONAH', 'NNP')),
#  (('--', ':'), ('JONAH', 'NNP'), ('.', '.')),
#  (('JONAH', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('There', 'EX')),
#  (('``', '``'), ('There', 'EX'), ('go', 'VB')),
#  (('There', 'EX'), ('go', 'VB'), ('the', 'DT')),
#  (('go', 'VB'), ('the', 'DT'), ('ships', 'NNS')),
#  (('the', 'DT'), ('ships', 'NNS'), (';', ':')),
#  (('ships', 'NNS'), (';', ':'), ('there', 'EX')),
#  ((';', ':'), ('there', 'EX'), ('is', 'VBZ')),
#  (('there', 'EX'), ('is', 'VBZ'), ('that', 'IN')),
#  (('is', 'VBZ'), ('that', 'IN'), ('Leviathan', 'NNP')),
#  (('that', 'IN'), ('Leviathan', 'NNP'), ('whom', 'WP')),
#  (('Leviathan', 'NNP'), ('whom', 'WP'), ('thou', 'VBD')),
#  (('whom', 'WP'), ('thou', 'VBD'), ('hast', 'NN')),
#  (('thou', 'VBD'), ('hast', 'NN'), ('made', 'VBN')),
#  (('hast', 'NN'), ('made', 'VBN'), ('to', 'TO')),
#  (('made', 'VBN'), ('to', 'TO'), ('play', 'VB')),
#  (('to', 'TO'), ('play', 'VB'), ('therein', 'RB')),
#  (('play', 'VB'), ('therein', 'RB'), ('.', '.')),
#  (('therein', 'RB'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('PSALMS', 'NNP')),
#  (('--', ':'), ('PSALMS', 'NNP'), ('.', '.')),
#  (('PSALMS', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('In', 'IN')),
#  (('``', '``'), ('In', 'IN'), ('that', 'DT')),
#  (('In', 'IN'), ('that', 'DT'), ('day', 'NN')),
#  (('that', 'DT'), ('day', 'NN'), (',', ',')),
#  (('day', 'NN'), (',', ','), ('the', 'DT')),
#  ((',', ','), ('the', 'DT'), ('Lord', 'NNP')),
#  (('the', 'DT'), ('Lord', 'NNP'), ('with', 'IN')),
#  (('Lord', 'NNP'), ('with', 'IN'), ('his', 'PRP$')),
#  (('with', 'IN'), ('his', 'PRP$'), ('sore', 'NN')),
#  (('his', 'PRP$'), ('sore', 'NN'), (',', ',')),
#  (('sore', 'NN'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('great', 'JJ')),
#  (('and', 'CC'), ('great', 'JJ'), (',', ',')),
#  (('great', 'JJ'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('strong', 'JJ')),
#  (('and', 'CC'), ('strong', 'JJ'), ('sword', 'NN')),
#  (('strong', 'JJ'), ('sword', 'NN'), (',', ',')),
#  (('sword', 'NN'), (',', ','), ('shall', 'MD')),
#  ((',', ','), ('shall', 'MD'), ('punish', 'VB')),
#  (('shall', 'MD'), ('punish', 'VB'), ('Leviathan', 'NNP')),
#  (('punish', 'VB'), ('Leviathan', 'NNP'), ('the', 'DT')),
#  (('Leviathan', 'NNP'), ('the', 'DT'), ('piercing', 'NN')),
#  (('the', 'DT'), ('piercing', 'NN'), ('serpent', 'NN')),
#  (('piercing', 'NN'), ('serpent', 'NN'), (',', ',')),
#  (('serpent', 'NN'), (',', ','), ('even', 'RB')),
#  ((',', ','), ('even', 'RB'), ('Leviathan', 'NNP')),
#  (('even', 'RB'), ('Leviathan', 'NNP'), ('that', 'IN')),
#  (('Leviathan', 'NNP'), ('that', 'IN'), ('crooked', 'VBD')),
#  (('that', 'IN'), ('crooked', 'VBD'), ('serpent', 'NN')),
#  (('crooked', 'VBD'), ('serpent', 'NN'), (';', ':')),
#  (('serpent', 'NN'), (';', ':'), ('and', 'CC')),
#  ((';', ':'), ('and', 'CC'), ('he', 'PRP')),
#  (('and', 'CC'), ('he', 'PRP'), ('shall', 'MD')),
#  (('he', 'PRP'), ('shall', 'MD'), ('slay', 'VB')),
#  (('shall', 'MD'), ('slay', 'VB'), ('the', 'DT')),
#  (('slay', 'VB'), ('the', 'DT'), ('dragon', 'NN')),
#  (('the', 'DT'), ('dragon', 'NN'), ('that', 'WDT')),
#  (('dragon', 'NN'), ('that', 'WDT'), ('is', 'VBZ')),
#  (('that', 'WDT'), ('is', 'VBZ'), ('in', 'IN')),
#  (('is', 'VBZ'), ('in', 'IN'), ('the', 'DT')),
#  (('in', 'IN'), ('the', 'DT'), ('sea', 'NN')),
#  (('the', 'DT'), ('sea', 'NN'), ('.', '.')),
#  (('sea', 'NN'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('ISAIAH', 'NNP')),
#  (('--', ':'), ('ISAIAH', 'NNP'), ("''", "''")),
#  (('ISAIAH', 'NNP'), ("''", "''"), ('And', 'CC')),
#  (("''", "''"), ('And', 'CC'), ('what', 'WP')),
#  (('And', 'CC'), ('what', 'WP'), ('thing', 'NN')),
#  (('what', 'WP'), ('thing', 'NN'), ('soever', 'NN')),
#  (('thing', 'NN'), ('soever', 'NN'), ('besides', 'IN')),
#  (('soever', 'NN'), ('besides', 'IN'), ('cometh', 'NN')),
#  (('besides', 'IN'), ('cometh', 'NN'), ('within', 'IN')),
#  (('cometh', 'NN'), ('within', 'IN'), ('the', 'DT')),
#  (('within', 'IN'), ('the', 'DT'), ('chaos', 'NN')),
#  (('the', 'DT'), ('chaos', 'NN'), ('of', 'IN')),
#  (('chaos', 'NN'), ('of', 'IN'), ('this', 'DT')),
#  (('of', 'IN'), ('this', 'DT'), ('monster', 'NN')),
#  (('this', 'DT'), ('monster', 'NN'), ("'s", 'POS')),
#  (('monster', 'NN'), ("'s", 'POS'), ('mouth', 'NN')),
#  (("'s", 'POS'), ('mouth', 'NN'), (',', ',')),
#  (('mouth', 'NN'), (',', ','), ('be', 'VB')),
#  ((',', ','), ('be', 'VB'), ('it', 'PRP')),
#  (('be', 'VB'), ('it', 'PRP'), ('beast', 'RBS')),
#  (('it', 'PRP'), ('beast', 'RBS'), (',', ',')),
#  (('beast', 'RBS'), (',', ','), ('boat', 'NN')),
#  ((',', ','), ('boat', 'NN'), (',', ',')),
#  (('boat', 'NN'), (',', ','), ('or', 'CC')),
#  ((',', ','), ('or', 'CC'), ('stone', 'NN')),
#  (('or', 'CC'), ('stone', 'NN'), (',', ',')),
#  (('stone', 'NN'), (',', ','), ('down', 'IN')),
#  ((',', ','), ('down', 'IN'), ('it', 'PRP')),
#  (('down', 'IN'), ('it', 'PRP'), ('goes', 'VBZ')),
#  (('it', 'PRP'), ('goes', 'VBZ'), ('all', 'DT')),
#  (('goes', 'VBZ'), ('all', 'DT'), ('incontinently', 'RB')),
#  (('all', 'DT'), ('incontinently', 'RB'), ('that', 'IN')),
#  (('incontinently', 'RB'), ('that', 'IN'), ('foul', 'JJ')),
#  (('that', 'IN'), ('foul', 'JJ'), ('great', 'JJ')),
#  (('foul', 'JJ'), ('great', 'JJ'), ('swallow', 'NN')),
#  (('great', 'JJ'), ('swallow', 'NN'), ('of', 'IN')),
#  (('swallow', 'NN'), ('of', 'IN'), ('his', 'PRP$')),
#  (('of', 'IN'), ('his', 'PRP$'), (',', ',')),
#  (('his', 'PRP$'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('perisheth', 'NNS')),
#  (('and', 'CC'), ('perisheth', 'NNS'), ('in', 'IN')),
#  (('perisheth', 'NNS'), ('in', 'IN'), ('the', 'DT')),
#  (('in', 'IN'), ('the', 'DT'), ('bottomless', 'NN')),
#  (('the', 'DT'), ('bottomless', 'NN'), ('gulf', 'NN')),
#  (('bottomless', 'NN'), ('gulf', 'NN'), ('of', 'IN')),
#  (('gulf', 'NN'), ('of', 'IN'), ('his', 'PRP$')),
#  (('of', 'IN'), ('his', 'PRP$'), ('paunch', 'NN')),
#  (('his', 'PRP$'), ('paunch', 'NN'), ('.', '.')),
#  (('paunch', 'NN'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('HOLLAND', 'NNP')),
#  (('--', ':'), ('HOLLAND', 'NNP'), ("'S", 'POS')),
#  (('HOLLAND', 'NNP'), ("'S", 'POS'), ('PLUTARCH', 'NNP')),
#  (("'S", 'POS'), ('PLUTARCH', 'NNP'), ("'S", 'POS')),
#  (('PLUTARCH', 'NNP'), ("'S", 'POS'), ('MORALS', 'NNP')),
#  (("'S", 'POS'), ('MORALS', 'NNP'), ('.', '.')),
#  (('MORALS', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('The', 'DT')),
#  (('``', '``'), ('The', 'DT'), ('Indian', 'JJ')),
#  (('The', 'DT'), ('Indian', 'JJ'), ('Sea', 'NNP')),
#  (('Indian', 'JJ'), ('Sea', 'NNP'), ('breedeth', 'VBD')),
#  (('Sea', 'NNP'), ('breedeth', 'VBD'), ('the', 'DT')),
#  (('breedeth', 'VBD'), ('the', 'DT'), ('most', 'RBS')),
#  (('the', 'DT'), ('most', 'RBS'), ('and', 'CC')),
#  (('most', 'RBS'), ('and', 'CC'), ('the', 'DT')),
#  (('and', 'CC'), ('the', 'DT'), ('biggest', 'JJS')),
#  (('the', 'DT'), ('biggest', 'JJS'), ('fishes', 'NNS')),
#  (('biggest', 'JJS'), ('fishes', 'NNS'), ('that', 'WDT')),
#  (('fishes', 'NNS'), ('that', 'WDT'), ('are', 'VBP')),
#  (('that', 'WDT'), ('are', 'VBP'), (':', ':')),
#  (('are', 'VBP'), (':', ':'), ('among', 'IN')),
#  ((':', ':'), ('among', 'IN'), ('which', 'WDT')),
#  (('among', 'IN'), ('which', 'WDT'), ('the', 'DT')),
#  (('which', 'WDT'), ('the', 'DT'), ('Whales', 'NNPS')),
#  (('the', 'DT'), ('Whales', 'NNPS'), ('and', 'CC')),
#  (('Whales', 'NNPS'), ('and', 'CC'), ('Whirlpooles', 'NNP')),
#  (('and', 'CC'), ('Whirlpooles', 'NNP'), ('called', 'VBD')),
#  (('Whirlpooles', 'NNP'), ('called', 'VBD'), ('Balaene', 'NNP')),
#  (('called', 'VBD'), ('Balaene', 'NNP'), (',', ',')),
#  (('Balaene', 'NNP'), (',', ','), ('take', 'VB')),
#  ((',', ','), ('take', 'VB'), ('up', 'RP')),
#  (('take', 'VB'), ('up', 'RP'), ('as', 'RB')),
#  (('up', 'RP'), ('as', 'RB'), ('much', 'RB')),
#  (('as', 'RB'), ('much', 'RB'), ('in', 'IN')),
#  (('much', 'RB'), ('in', 'IN'), ('length', 'NN')),
#  (('in', 'IN'), ('length', 'NN'), ('as', 'IN')),
#  (('length', 'NN'), ('as', 'IN'), ('four', 'CD')),
#  (('as', 'IN'), ('four', 'CD'), ('acres', 'NNS')),
#  (('four', 'CD'), ('acres', 'NNS'), ('or', 'CC')),
#  (('acres', 'NNS'), ('or', 'CC'), ('arpens', 'NNS')),
#  (('or', 'CC'), ('arpens', 'NNS'), ('of', 'IN')),
#  (('arpens', 'NNS'), ('of', 'IN'), ('land', 'NN')),
#  (('of', 'IN'), ('land', 'NN'), ('.', '.')),
#  (('land', 'NN'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('HOLLAND', 'NNP')),
#  (('--', ':'), ('HOLLAND', 'NNP'), ("'S", 'POS')),
#  (('HOLLAND', 'NNP'), ("'S", 'POS'), ('PLINY', 'NNP')),
#  (("'S", 'POS'), ('PLINY', 'NNP'), ('.', '.')),
#  (('PLINY', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('Scarcely', 'RB')),
#  (('``', '``'), ('Scarcely', 'RB'), ('had', 'VBD')),
#  (('Scarcely', 'RB'), ('had', 'VBD'), ('we', 'PRP')),
#  (('had', 'VBD'), ('we', 'PRP'), ('proceeded', 'VBD')),
#  (('we', 'PRP'), ('proceeded', 'VBD'), ('two', 'CD')),
#  (('proceeded', 'VBD'), ('two', 'CD'), ('days', 'NNS')),
#  (('two', 'CD'), ('days', 'NNS'), ('on', 'IN')),
#  (('days', 'NNS'), ('on', 'IN'), ('the', 'DT')),
#  (('on', 'IN'), ('the', 'DT'), ('sea', 'NN')),
#  (('the', 'DT'), ('sea', 'NN'), (',', ',')),
#  (('sea', 'NN'), (',', ','), ('when', 'WRB')),
#  ((',', ','), ('when', 'WRB'), ('about', 'IN')),
#  (('when', 'WRB'), ('about', 'IN'), ('sunrise', 'NN')),
#  (('about', 'IN'), ('sunrise', 'NN'), ('a', 'DT')),
#  (('sunrise', 'NN'), ('a', 'DT'), ('great', 'JJ')),
#  (('a', 'DT'), ('great', 'JJ'), ('many', 'JJ')),
#  (('great', 'JJ'), ('many', 'JJ'), ('Whales', 'NNS')),
#  (('many', 'JJ'), ('Whales', 'NNS'), ('and', 'CC')),
#  (('Whales', 'NNS'), ('and', 'CC'), ('other', 'JJ')),
#  (('and', 'CC'), ('other', 'JJ'), ('monsters', 'NNS')),
#  (('other', 'JJ'), ('monsters', 'NNS'), ('of', 'IN')),
#  (('monsters', 'NNS'), ('of', 'IN'), ('the', 'DT')),
#  (('of', 'IN'), ('the', 'DT'), ('sea', 'NN')),
#  (('the', 'DT'), ('sea', 'NN'), (',', ',')),
#  (('sea', 'NN'), (',', ','), ('appeared', 'VBD')),
#  ((',', ','), ('appeared', 'VBD'), ('.', '.')),
#  (('appeared', 'VBD'), ('.', '.'), ('Among', 'IN')),
#  (('.', '.'), ('Among', 'IN'), ('the', 'DT')),
#  (('Among', 'IN'), ('the', 'DT'), ('former', 'JJ')),
#  (('the', 'DT'), ('former', 'JJ'), (',', ',')),
#  (('former', 'JJ'), (',', ','), ('one', 'CD')),
#  ((',', ','), ('one', 'CD'), ('was', 'VBD')),
#  (('one', 'CD'), ('was', 'VBD'), ('of', 'IN')),
#  (('was', 'VBD'), ('of', 'IN'), ('a', 'DT')),
#  (('of', 'IN'), ('a', 'DT'), ('most', 'RBS')),
#  (('a', 'DT'), ('most', 'RBS'), ('monstrous', 'JJ')),
#  (('most', 'RBS'), ('monstrous', 'JJ'), ('size', 'NN')),
#  (('monstrous', 'JJ'), ('size', 'NN'), ('.', '.')),
#  (('size', 'NN'), ('.', '.'), ('...', ':')),
#  (('.', '.'), ('...', ':'), ('This', 'DT')),
#  (('...', ':'), ('This', 'DT'), ('came', 'VBD')),
#  (('This', 'DT'), ('came', 'VBD'), ('towards', 'NNS')),
#  (('came', 'VBD'), ('towards', 'NNS'), ('us', 'PRP')),
#  (('towards', 'NNS'), ('us', 'PRP'), (',', ',')),
#  (('us', 'PRP'), (',', ','), ('open-mouthed', 'JJ')),
#  ((',', ','), ('open-mouthed', 'JJ'), (',', ',')),
#  (('open-mouthed', 'JJ'), (',', ','), ('raising', 'VBG')),
#  ((',', ','), ('raising', 'VBG'), ('the', 'DT')),
#  (('raising', 'VBG'), ('the', 'DT'), ('waves', 'NNS')),
#  (('the', 'DT'), ('waves', 'NNS'), ('on', 'IN')),
#  (('waves', 'NNS'), ('on', 'IN'), ('all', 'DT')),
#  (('on', 'IN'), ('all', 'DT'), ('sides', 'NNS')),
#  (('all', 'DT'), ('sides', 'NNS'), (',', ',')),
#  (('sides', 'NNS'), (',', ','), ('and', 'CC')),
#  ((',', ','), ('and', 'CC'), ('beating', 'VBG')),
#  (('and', 'CC'), ('beating', 'VBG'), ('the', 'DT')),
#  (('beating', 'VBG'), ('the', 'DT'), ('sea', 'NN')),
#  (('the', 'DT'), ('sea', 'NN'), ('before', 'IN')),
#  (('sea', 'NN'), ('before', 'IN'), ('him', 'PRP')),
#  (('before', 'IN'), ('him', 'PRP'), ('into', 'IN')),
#  (('him', 'PRP'), ('into', 'IN'), ('a', 'DT')),
#  (('into', 'IN'), ('a', 'DT'), ('foam', 'NN')),
#  (('a', 'DT'), ('foam', 'NN'), ('.', '.')),
#  (('foam', 'NN'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('TOOKE', 'NNP')),
#  (('--', ':'), ('TOOKE', 'NNP'), ("'S", 'POS')),
#  (('TOOKE', 'NNP'), ("'S", 'POS'), ('LUCIAN', 'NNP')),
#  (("'S", 'POS'), ('LUCIAN', 'NNP'), ('.', '.')),
#  (('LUCIAN', 'NNP'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('THE', 'DT')),
#  (('``', '``'), ('THE', 'DT'), ('TRUE', 'NNP')),
#  (('THE', 'DT'), ('TRUE', 'NNP'), ('HISTORY', 'NNP')),
#  (('TRUE', 'NNP'), ('HISTORY', 'NNP'), ('.', '.')),
#  (('HISTORY', 'NNP'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('``', '``')),
#  (("''", "''"), ('``', '``'), ('He', 'PRP')),
#  (('``', '``'), ('He', 'PRP'), ('visited', 'VBD')),
#  (('He', 'PRP'), ('visited', 'VBD'), ('this', 'DT')),
#  (('visited', 'VBD'), ('this', 'DT'), ('country', 'NN')),
#  (('this', 'DT'), ('country', 'NN'), ('also', 'RB')),
#  (('country', 'NN'), ('also', 'RB'), ('with', 'IN')),
#  (('also', 'RB'), ('with', 'IN'), ('a', 'DT')),
#  (('with', 'IN'), ('a', 'DT'), ('view', 'NN')),
#  (('a', 'DT'), ('view', 'NN'), ('of', 'IN')),
#  (('view', 'NN'), ('of', 'IN'), ('catching', 'VBG')),
#  (('of', 'IN'), ('catching', 'VBG'), ('horse-whales', 'NNS')),
#  (('catching', 'VBG'), ('horse-whales', 'NNS'), (',', ',')),
#  (('horse-whales', 'NNS'), (',', ','), ('which', 'WDT')),
#  ((',', ','), ('which', 'WDT'), ('had', 'VBD')),
#  (('which', 'WDT'), ('had', 'VBD'), ('bones', 'NNS')),
#  (('had', 'VBD'), ('bones', 'NNS'), ('of', 'IN')),
#  (('bones', 'NNS'), ('of', 'IN'), ('very', 'RB')),
#  (('of', 'IN'), ('very', 'RB'), ('great', 'JJ')),
#  (('very', 'RB'), ('great', 'JJ'), ('value', 'NN')),
#  (('great', 'JJ'), ('value', 'NN'), ('for', 'IN')),
#  (('value', 'NN'), ('for', 'IN'), ('their', 'PRP$')),
#  (('for', 'IN'), ('their', 'PRP$'), ('teeth', 'NNS')),
#  (('their', 'PRP$'), ('teeth', 'NNS'), (',', ',')),
#  (('teeth', 'NNS'), (',', ','), ('of', 'IN')),
#  ((',', ','), ('of', 'IN'), ('which', 'WDT')),
#  (('of', 'IN'), ('which', 'WDT'), ('he', 'PRP')),
#  (('which', 'WDT'), ('he', 'PRP'), ('brought', 'VBD')),
#  (('he', 'PRP'), ('brought', 'VBD'), ('some', 'DT')),
#  (('brought', 'VBD'), ('some', 'DT'), ('to', 'TO')),
#  (('some', 'DT'), ('to', 'TO'), ('the', 'DT')),
#  (('to', 'TO'), ('the', 'DT'), ('king', 'NN')),
#  (('the', 'DT'), ('king', 'NN'), ('.', '.')),
#  (('king', 'NN'), ('.', '.'), ('...', ':')),
#  (('.', '.'), ('...', ':'), ('The', 'DT')),
#  (('...', ':'), ('The', 'DT'), ('best', 'JJS')),
#  (('The', 'DT'), ('best', 'JJS'), ('whales', 'NNS')),
#  (('best', 'JJS'), ('whales', 'NNS'), ('were', 'VBD')),
#  (('whales', 'NNS'), ('were', 'VBD'), ('catched', 'VBN')),
#  (('were', 'VBD'), ('catched', 'VBN'), ('in', 'IN')),
#  (('catched', 'VBN'), ('in', 'IN'), ('his', 'PRP$')),
#  (('in', 'IN'), ('his', 'PRP$'), ('own', 'JJ')),
#  (('his', 'PRP$'), ('own', 'JJ'), ('country', 'NN')),
#  (('own', 'JJ'), ('country', 'NN'), (',', ',')),
#  (('country', 'NN'), (',', ','), ('of', 'IN')),
#  ((',', ','), ('of', 'IN'), ('which', 'WDT')),
#  (('of', 'IN'), ('which', 'WDT'), ('some', 'DT')),
#  (('which', 'WDT'), ('some', 'DT'), ('were', 'VBD')),
#  (('some', 'DT'), ('were', 'VBD'), ('forty-eight', 'JJ')),
#  (('were', 'VBD'), ('forty-eight', 'JJ'), (',', ',')),
#  (('forty-eight', 'JJ'), (',', ','), ('some', 'DT')),
#  ((',', ','), ('some', 'DT'), ('fifty', 'JJ')),
#  (('some', 'DT'), ('fifty', 'JJ'), ('yards', 'NNS')),
#  (('fifty', 'JJ'), ('yards', 'NNS'), ('long', 'RB')),
#  (('yards', 'NNS'), ('long', 'RB'), ('.', '.')),
#  (('long', 'RB'), ('.', '.'), ('He', 'PRP')),
#  (('.', '.'), ('He', 'PRP'), ('said', 'VBD')),
#  (('He', 'PRP'), ('said', 'VBD'), ('that', 'IN')),
#  (('said', 'VBD'), ('that', 'IN'), ('he', 'PRP')),
#  (('that', 'IN'), ('he', 'PRP'), ('was', 'VBD')),
#  (('he', 'PRP'), ('was', 'VBD'), ('one', 'CD')),
#  (('was', 'VBD'), ('one', 'CD'), ('of', 'IN')),
#  (('one', 'CD'), ('of', 'IN'), ('six', 'CD')),
#  (('of', 'IN'), ('six', 'CD'), ('who', 'WP')),
#  (('six', 'CD'), ('who', 'WP'), ('had', 'VBD')),
#  (('who', 'WP'), ('had', 'VBD'), ('killed', 'VBN')),
#  (('had', 'VBD'), ('killed', 'VBN'), ('sixty', 'RB')),
#  (('killed', 'VBN'), ('sixty', 'RB'), ('in', 'IN')),
#  (('sixty', 'RB'), ('in', 'IN'), ('two', 'CD')),
#  (('in', 'IN'), ('two', 'CD'), ('days', 'NNS')),
#  (('two', 'CD'), ('days', 'NNS'), ('.', '.')),
#  (('days', 'NNS'), ('.', '.'), ("''", "''")),
#  (('.', '.'), ("''", "''"), ('--', ':')),
#  (("''", "''"), ('--', ':'), ('OTHER', 'NNP')),
#  (('--', ':'), ('OTHER', 'NNP'), ('OR', 'NNP')),
#  (('OTHER', 'NNP'), ('OR', 'NNP'), ('OCTHER', 'NNP')),
#  (('OR', 'NNP'), ('OCTHER', 'NNP'), ("'S", 'POS')),
#  (('OCTHER', 'NNP'), ("'S", 'POS'), ('VERBAL', 'NNP')),
#  (("'S", 'POS'), ('VERBAL', 'NNP'), ('NARRATIVE', 'NNP')),
#  (('VERBAL', 'NNP'), ('NARRATIVE', 'NNP'), ('TAKEN', 'NNP')),
#  (('NARRATIVE', 'NNP'), ('TAKEN', 'NNP'), ('DOWN', 'NNP')),
#  (('TAKEN', 'NNP'), ('DOWN', 'NNP'), ('FROM', 'NNP')),
#  (('DOWN', 'NNP'), ('FROM', 'NNP'), ('HIS', 'NNP')),
#  (('FROM', 'NNP'), ('HIS', 'NNP'), ('MOUTH', 'NNP')),
#  (('HIS', 'NNP'), ('MOUTH', 'NNP'), ('BY', 'NNP')),
#  (('MOUTH', 'NNP'), ('BY', 'NNP'), ('KING', 'NNP')),
#  (('BY', 'NNP'), ('KING', 'NNP'), ('ALFRED', 'NNP')),
#  (('KING', 'NNP'), ('ALFRED', 'NNP'), (',', ',')),
#  (('ALFRED', 'NNP'), (',', ','), ('A.D.', 'NNP')),
#  ((',', ','), ('A.D.', 'NNP'), ('890', 'CD')),
#  (('A.D.', 'NNP'), ('890', 'CD'), ('.', '.')),
#  (('890', 'CD'), ('.', '.'), ('``', '``')),
#  (('.', '.'), ('``', '``'), ('And', 'CC')),
#  (('``', '``'), ('And', 'CC'), ('whereas', 'VB')),
#  (('And', 'CC'), ('whereas', 'VB'), ('all', 'PDT')),
#  (('whereas', 'VB'), ('all', 'PDT'), ('the', 'DT')),
#  (('all', 'PDT'), ('the', 'DT'), ('other', 'JJ')),
#  (('the', 'DT'), ('other', 'JJ'), ('things', 'NNS')),
#  (('other', 'JJ'), ('things', 'NNS'), (',', ',')),
#  (('things', 'NNS'), (',', ','), ('whether', 'IN')),
#  ((',', ','), ('whether', 'IN'), ('beast', 'NN')),
#  (('whether', 'IN'), ('beast', 'NN'), ('or', 'CC')),
#  (('beast', 'NN'), ('or', 'CC'), ('vessel', 'NN')),
#  (('or', 'CC'), ('vessel', 'NN'), (',', ',')),
#  ...]

# %%
# moby_dick_freqdist.keys()

# %%
# Normalize the frequency by dividing each word's frequency by the total number
# of words in the corpus

# Obtain a total word count in the corpus
total_word_count = sum(moby_dick_freqdist.values())

# View the top 25 words by normalize frequency distribution
moby_dick_top_25 = moby_dick_freqdist.most_common(25)
print("Word\t\t\tNormalized Frequency")
for word in moby_dick_top_25:
    normalized_frequency = word[1] / total_word_count
    print("{} \t\t\t {:.4}".format(word[0], normalized_frequency))
# Out:
# Word			Normalized Frequency
# , 			 0.0753
# the 			 0.05378
# . 			 0.02865
# of 			 0.02554
# and 			 0.02357
# a 			 0.01782
# to 			 0.0177
# ; 			 0.01636
# in 			 0.01532
# that 			 0.01168
# his 			 0.009642
# it 			 0.00861
# I 			 0.008285
# ! 			 0.006928
# is 			 0.006752
# -- 			 0.006717
# with 			 0.006505
# he 			 0.006501
# was 			 0.006426
# as 			 0.006352
# '' 			 0.006332
# 's 			 0.006215
# `` 			 0.005709
# all 			 0.005662
# for 			 0.00554

# %%
print(total_word_count)
# Out:
# 255038
